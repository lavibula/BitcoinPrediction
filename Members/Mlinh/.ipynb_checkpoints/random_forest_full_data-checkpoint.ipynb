# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, date
import seaborn as sns

# %% [markdown]
# # Load Data
# * Handle missing values, duplicated values, outlier

# %%
total = pd.read_csv("https://raw.githubusercontent.com/lavibula/ML20222.PredictionBitcoin/main/data/saved_data_ASC.csv")
total['Date'] = pd.to_datetime(total['Date'])

df = total.set_index('Date')
df.head()
# Out:
#             BTC_close  BTC_open  BTC_high  BTC_low  BTC_volume
# Date
# 2010-07-20        0.1       0.1       0.1      0.1        0.26  \
# 2010-07-21        0.1       0.1       0.1      0.1        0.58
# 2010-07-22        0.1       0.1       0.1      0.1        2.16
# 2010-07-23        0.1       0.1       0.1      0.1        2.40
# 2010-07-24        0.1       0.1       0.1      0.1        0.50
#
#             Active_Addr_Cnt  Difficulty  Mean_Block_Size(in_bytes)
# Date
# 2010-07-20            936.0       182.0                1090.745856  \
# 2010-07-21            784.0       182.0                 603.821256
# 2010-07-22            594.0       182.0                 572.443182
# 2010-07-23            655.0       182.0                 530.932990
# 2010-07-24            959.0       182.0                1519.539683
#
#             Sum_Block_Weight  Total_Fees(USD)  ...  ETH  LTC  DOGE  XRP
# Date                                           ...
# 2010-07-20          789700.0         0.000000  ...  0.0  0.0   0.0  0.0  \
# 2010-07-21          499964.0         0.000000  ...  0.0  0.0   0.0  0.0
# 2010-07-22          403000.0         0.000000  ...  0.0  0.0   0.0  0.0
# 2010-07-23          412004.0         0.000606  ...  0.0  0.0   0.0  0.0
# 2010-07-24         1148772.0         0.000000  ...  0.0  0.0   0.0  0.0
#
#               GOLD  SILVER   COPPER   S&P500       DJI    JP225
# Date
# 2010-07-20  1191.7  17.693     0.00  1083.48  10229.96  9300.46
# 2010-07-21  1191.8  17.803     0.00  1069.59  10120.53  9278.83
# 2010-07-22  1195.6  18.120  7002.75  1093.67  10322.30  9220.88
# 2010-07-23  1187.8  18.101  7018.25  1102.66  10424.62  9430.96
# 2010-07-24  1187.8  18.101  7018.25  1102.66  10424.62  9430.96
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (4654, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4654 entries, 2010-07-20 to 2023-04-16
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BTC_close                   4654 non-null   float64
#  1   BTC_open                    4654 non-null   float64
#  2   BTC_high                    4654 non-null   float64
#  3   BTC_low                     4654 non-null   float64
#  4   BTC_volume                  4654 non-null   float64
#  5   Active_Addr_Cnt             4654 non-null   float64
#  6   Difficulty                  4654 non-null   float64
#  7   Mean_Block_Size(in_bytes)   4654 non-null   float64
#  8   Sum_Block_Weight            4654 non-null   float64
#  9   Total_Fees(USD)             4654 non-null   float64
#  10  Mean_Hashrate               4654 non-null   float64
#  11  Xfer_Cnt                    4654 non-null   float64
#  12  Mean_Tx_size(native_units)  4654 non-null   float64
#  13  ETH                         4654 non-null   float64
#  14  LTC                         4654 non-null   float64
#  15  DOGE                        4654 non-null   float64
#  16  XRP                         4654 non-null   float64
#  17  GOLD                        4654 non-null   float64
#  18  SILVER                      4654 non-null   float64
#  19  COPPER                      4654 non-null   float64
#  20  S&P500                      4654 non-null   float64
#  21  DJI                         4654 non-null   float64
#  22  JP225                       4654 non-null   float64
# dtypes: float64(23)
# memory usage: 872.6 KB

# %%
df.describe()
# Out:
#           BTC_close      BTC_open      BTC_high       BTC_low   BTC_volume
# count   4654.000000   4654.000000   4654.000000   4654.000000  4654.000000  \
# mean    8950.828126   8944.396197   9182.648904   8680.543532   144.272183
# std    14517.759120  14515.100053  14900.138248  14078.916437   199.685947
# min        0.100000      0.100000      0.100000      0.000000     0.170000
# 25%      140.475000    140.400000    145.800000    135.825000    25.407500
# 50%      916.050000    915.050000    934.150000    877.350000    63.605000
# 75%     9932.450000   9926.450000  10231.950000   9636.050000   158.375000
# max    67527.900000  67528.700000  68990.600000  66334.900000   999.530000
#
#        Active_Addr_Cnt    Difficulty  Mean_Block_Size(in_bytes)
# count     4.654000e+03  4.654000e+03               4.654000e+03  \
# mean      4.974545e+05  7.399910e+12               6.883463e+05
# std       3.731797e+05  1.103629e+13               4.990862e+05
# min       4.080000e+02  1.820000e+02               4.164167e+02
# 25%       8.702175e+04  1.322172e+08               1.656955e+05
# 50%       5.389900e+05  2.840750e+11               7.887917e+05
# 75%       8.174050e+05  1.389755e+13               1.087807e+06
# max       1.366494e+06  4.788780e+13               2.535436e+06
#
#        Sum_Block_Weight  Total_Fees(USD)  ...          ETH          LTC
# count      4.654000e+03     4.654000e+03  ...  4654.000000  4654.000000  \
# mean       3.329426e+08     5.498044e+05  ...   505.010290    45.052975
# std        2.151278e+08     1.528054e+06  ...   945.449318    63.364718
# min        2.841400e+05     0.000000e+00  ...     0.000000     0.000000
# 25%        1.124594e+08     3.741492e+03  ...     0.000000     0.000000
# 50%        4.066180e+08     6.090908e+04  ...    12.430000     3.870000
# 75%        5.072356e+08     4.321621e+05  ...   396.107500    67.199500
# max        7.584308e+08     2.139776e+07  ...  4808.380000   386.820000
#
#               DOGE          XRP         GOLD       SILVER        COPPER
# count  4654.000000  4654.000000  4654.000000  4654.000000   4654.000000  \
# mean      0.026408     0.229873  1474.337129    21.657901   7112.199345
# std       0.069391     0.334681   253.778406     6.479395   1491.343889
# min       0.000000     0.000000  1049.600000    11.772000      0.000000
# 25%       0.000000     0.000000  1260.025000    16.624500   5947.125000
# 50%       0.000000     0.008870  1371.850000    19.570000   6962.000000
# 75%       0.003335     0.350712  1721.025000    25.340750   8151.437500
# max       0.686880     2.780000  2069.400000    48.599000  10674.000000
#
#             S&P500           DJI         JP225
# count  4654.000000   4654.000000   4654.000000
# mean   2492.349280  21487.496401  18751.425404
# std     989.044608   7511.506584   6322.971966
# min    1047.220000   9985.810000   8160.010000
# 25%    1697.435000  15464.300000  14313.030000
# 50%    2204.720000  19161.280000  19435.830000
# 75%    3046.155000  26828.202500  22902.512500
# max    4796.560000  36799.650000  30670.100000
#
# [8 rows x 23 columns]

# %%
sns.heatmap(df.corr(), cmap="RdBu")
# Out:
# <Axes: >

# %% [markdown]
# # Slpit Data (Testing, Training Data Sets)

# %%
from datetime import datetime
Start_day = date(2016, 3, 10)
End_day = date(2023,4,16)
# train, test

for index in total.index:
    total.loc[index, "Date"] = datetime.strptime(str(total.loc[index, "Date"])[:10], '%Y-%m-%d').date()
total = total[(total["Date"] >= Start_day) & (total["Date"] <= End_day)].reset_index(drop = True)
X = total.drop(["Date"], axis=1)[:-1]
y = total["BTC_close"][1:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, shuffle=False)

# In thông tin kích thước các tập dữ liệu
print("Kích thước X_train:", X_train.shape)
print("Kích thước y_train:", y_train.shape)
print("Kích thước X_test:", X_test.shape)
print("Kích thước y_test:", y_test.shape)
# Out:
# Kích thước X_train: (1944, 23)
# Kích thước y_train: (1944,)
# Kích thước X_test: (649, 23)
# Kích thước y_test: (649,)

# %%
print("Kích thước X_train:", X_train.shape)
print("Kích thước y_train:", y_train.shape)
print("Kích thước X_test:", X_test.shape)
print("Kích thước y_test:", y_test.shape)
# Out:
# Kích thước X_train: (1944, 23)
# Kích thước y_train: (1944,)
# Kích thước X_test: (649, 23)
# Kích thước y_test: (649,)

# %% [markdown]
# # Load Model

# %%
#import sklearn modules
import time
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %% [markdown]
# ## Default

# %%
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np
y_train_pred = rf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Square Error (RMSE):", rmse)

#MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print(" Mean Absolute Percentage Error (MAPE):", mape)
print()
AUC = AUC(y_test, y_pred)
#AUC
print("AUC test:", AUC)
# Out:
# Test accuracy for train set
# Root Mean Square Error (RMSE): 287.09441278054527
# Mean Absolute Percentage Error (MAPE): 0.010957226383499172
#
# Test accuracy for test set
# Root Mean Square Error (RMSE): 2083.8325306655533
#  Mean Absolute Percentage Error (MAPE): 0.05290546937101689
#
# AUC test: 0.4876543209876543

# %% [markdown]
# ## Tuning

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# Define the range of values for n_estimators
n_estimators = [int(x) for x in np.linspace(start=100, stop=1000, num=10)]
max_depth = [int(x) for x in np.linspace(2, 10, num = 5)]
max_features = [None]
bootstrap = [False] # method used to sample data points

param_grid = {'n_estimators': n_estimators,

'max_features': max_features,

'max_depth': max_depth,

'bootstrap': bootstrap}

print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000], 'max_features': ['sqrt', 'log2', None], 'max_depth': [2, 4, 6, 8, 10], 'bootstrap': [True, False]}

# %% [markdown]
# ### Randomized Search

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer

scoring = make_scorer(mean_squared_error, greater_is_better=False)

# Create the RandomizedSearchCV object with early stopping
rf_random = RandomizedSearchCV(estimator=rf, param_distributions = param_grid, scoring=scoring,
                                   cv=200, refit=True, verbose=2,
                                   n_jobs = -1, random_state=42)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomizedSearchCV(cv=10, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [2, 4, 6, 8, 10],
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000]},
#                    random_state=42,
#                    scoring=make_scorer(mean_squared_error, greater_is_better=False),
#                    verbose=2)

# %%
print ('Best Parameters: ', rf_random.best_params_)
print("Best RMSE Score: ", rf_random.best_score_)
# Out:
# Best Parameters:  {'n_estimators': 400, 'max_features': None, 'max_depth': 6, 'bootstrap': False}
# Best RMSE Score:  -58829650.50113177

# %% [markdown]
# ### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# Define the scoring function (negative mean squared error)
scoring = make_scorer(mean_squared_error, greater_is_better=False)

# Create the GridSearchCV object with early stopping
rf_Grid = GridSearchCV(estimator=rf, param_grid=param_grid, scoring=scoring,
                           cv=200, refit=True, verbose=2,
                           n_jobs=-1)

# %%
rf_Grid.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  23.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=700; total time= 1.1min
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=   9.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  10.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  30.6s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  30.8s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=  13.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  17.8s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  17.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=  19.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   5.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   6.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=   8.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=   9.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   3.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=500; total time=   6.4s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=600; total time=   7.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=600; total time=   8.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=700; total time=   7.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=800; total time=   9.4s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=900; total time=  10.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=1000; total time=   9.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=1000; total time=  11.2s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=300; total time=   7.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=500; total time=  10.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=600; total time=  12.7s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=700; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=800; total time=  16.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=800; total time=  17.1s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=900; total time=  19.1s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=1000; total time=  21.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=400; total time=   4.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=400; total time=   4.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=500; total time=   5.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=600; total time=   7.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=700; total time=   7.6s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=800; total time=   8.6s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=800; total time=   8.7s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=900; total time=   9.8s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=1000; total time=  11.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=600; total time=   6.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=700; total time=   7.8s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=800; total time=   9.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=800; total time=   9.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=900; total time=  10.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=1000; total time=  11.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=100; total time=   3.7s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=200; total time=   7.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=300; total time=  10.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=400; total time=  14.0s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=500; total time=  17.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=500; total time=  16.7s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=600; total time=  20.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=700; total time=  24.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=800; total time=  31.9s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=900; total time=  31.3s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=900; total time=  30.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=1000; total time=  34.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=400; total time=   5.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=500; total time=   6.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=600; total time=   8.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=700; total time=   9.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=700; total time=   9.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=800; total time=  10.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=900; total time=  11.8s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=1000; total time=  13.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=500; total time=   6.8s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=600; total time=   8.1s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=600; total time=   8.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=700; total time=   9.6s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=800; total time=  10.6s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=900; total time=  12.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=1000; total time=  13.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=1000; total time=  13.4s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=300; total time=  14.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=300; total time=  14.5s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=400; total time=  19.9s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=500; total time=  22.9s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=600; total time=  27.4s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=700; total time=  31.9s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=700; total time=  32.4s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=800; total time=  37.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=900; total time=  40.7s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=1000; total time=  45.6s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=300; total time=   4.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=600; total time=   9.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=700; total time=  10.9s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=700; total time=  10.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=800; total time=  12.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=600; total time=   9.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=700; total time=  10.9s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=800; total time=  12.3s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  15.2s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=200; total time=  11.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=300; total time=  17.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=400; total time=  23.2s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=500; total time=  28.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=500; total time=  28.0s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=600; total time=  34.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=700; total time=  39.4s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=800; total time=  45.4s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=900; total time=  52.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=900; total time=  49.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  23.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  22.5s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=700; total time= 1.1min
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  10.2s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  30.0s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=  12.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=  12.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=  13.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  17.9s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  17.9s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=  19.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   5.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   4.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   6.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   7.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=   8.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=   9.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  10.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   3.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.3s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=500; total time=   6.3s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=600; total time=   8.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=700; total time=   8.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=700; total time=   8.4s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=800; total time=   9.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=900; total time=   9.3s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=1000; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=100; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=100; total time=   2.5s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=300; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=400; total time=   9.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=500; total time=  10.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=600; total time=  12.7s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=700; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=800; total time=  16.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=800; total time=  16.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=900; total time=  19.1s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=1000; total time=  21.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=300; total time=   3.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=400; total time=   4.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=500; total time=   5.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=600; total time=   7.0s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=700; total time=   7.8s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=700; total time=   7.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=800; total time=   8.6s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=900; total time=   9.9s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=1000; total time=  11.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=300; total time=   3.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=600; total time=   6.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=700; total time=   7.9s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=800; total time=   8.9s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=900; total time=  10.3s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=900; total time=   9.9s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=1000; total time=  11.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=300; total time=  10.6s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=400; total time=  14.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=400; total time=  13.7s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=500; total time=  16.9s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=600; total time=  20.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=700; total time=  24.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=800; total time=  31.9s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=800; total time=  27.8s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=900; total time=  30.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=1000; total time=  34.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=400; total time=   5.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=500; total time=   6.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=600; total time=   8.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=700; total time=   9.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=700; total time=   9.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=800; total time=  10.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=900; total time=  11.8s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=1000; total time=  13.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=500; total time=   6.8s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=600; total time=   8.1s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=600; total time=   8.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=700; total time=   9.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=800; total time=  10.6s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=900; total time=  12.1s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=1000; total time=  13.1s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=1000; total time=  13.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=300; total time=  14.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=300; total time=  14.7s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=400; total time=  19.9s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=500; total time=  23.0s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=600; total time=  27.2s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=700; total time=  32.0s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=700; total time=  32.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=800; total time=  37.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=900; total time=  40.4s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=1000; total time=  45.8s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=300; total time=   4.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=500; total time=   7.9s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=600; total time=   9.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=700; total time=  10.9s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=800; total time=  12.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=500; total time=   7.7s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=600; total time=   9.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=700; total time=  10.8s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=900; total time=  13.6s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  15.3s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=100; total time=   5.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=200; total time=  11.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=300; total time=  17.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=400; total time=  23.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=400; total time=  22.2s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=500; total time=  28.3s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=600; total time=  34.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=700; total time=  39.9s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=800; total time=  45.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=800; total time=  45.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  24.0s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=700; total time= 1.1min
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.0s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  10.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  30.1s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  30.6s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=  10.6s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=   9.6s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  17.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   5.8s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=  20.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   5.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   7.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=   8.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=   9.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   2.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   3.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=500; total time=   6.4s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=600; total time=   7.7s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=600; total time=   8.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=700; total time=   7.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=800; total time=   9.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=900; total time=  10.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=1000; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=1000; total time=  11.1s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=200; total time=   5.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=300; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=400; total time=   9.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=500; total time=  11.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=500; total time=  10.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=600; total time=  12.6s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=700; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=800; total time=  16.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=900; total time=  19.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=900; total time=  19.0s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=1000; total time=  21.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=300; total time=   3.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=500; total time=   5.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=600; total time=   7.1s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=600; total time=   6.7s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=700; total time=   7.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=800; total time=   8.6s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=900; total time=   9.9s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=1000; total time=  11.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=1000; total time=  11.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=400; total time=   4.5s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=600; total time=   6.8s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=600; total time=   6.7s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=700; total time=   7.8s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=800; total time=   9.0s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=900; total time=  10.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=1000; total time=  11.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=1000; total time=  11.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=300; total time=  10.7s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=300; total time=  10.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=400; total time=  14.0s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=500; total time=  17.0s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=600; total time=  20.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=700; total time=  24.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=700; total time=  27.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=800; total time=  29.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=900; total time=  30.7s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=1000; total time=  34.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=400; total time=   5.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=500; total time=   6.8s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=600; total time=   8.3s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=700; total time=   9.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=800; total time=  10.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=800; total time=  10.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=900; total time=  11.7s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=1000; total time=  13.2s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=100; total time=   1.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=500; total time=   6.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=600; total time=   8.1s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=700; total time=   9.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=800; total time=  10.8s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=800; total time=  10.5s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=900; total time=  12.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=1000; total time=  13.5s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=100; total time=   4.6s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=200; total time=   9.2s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=300; total time=  14.5s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=400; total time=  20.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=500; total time=  23.8s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=500; total time=  22.4s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=600; total time=  27.2s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=700; total time=  32.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=800; total time=  37.6s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=900; total time=  41.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=900; total time=  40.5s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=1000; total time=  45.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=300; total time=   4.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=500; total time=   7.9s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=600; total time=   9.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=700; total time=  10.9s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=800; total time=  12.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=900; total time=  13.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=900; total time=  13.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=600; total time=   9.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=700; total time=  11.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=700; total time=  10.9s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=900; total time=  13.7s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=100; total time=   6.0s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=100; total time=   5.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=200; total time=  11.4s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=300; total time=  17.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=300; total time=  17.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=400; total time=  22.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=500; total time=  28.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=600; total time=  34.4s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=700; total time=  40.3s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=700; total time=  39.1s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=800; total time=  45.6s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=900; total time=  51.9s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=1000; total time=  57.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# ...
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   5.8s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=  20.1s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   5.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   7.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=   8.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=   9.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  11.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  11.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.3s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=500; total time=   6.7s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=600; total time=   8.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=700; total time=   8.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=800; total time=   9.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=800; total time=   9.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=900; total time=   8.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=1000; total time=  11.1s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=200; total time=   5.0s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=200; total time=   5.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=300; total time=   7.4s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=400; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=500; total time=  11.1s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=600; total time=  13.0s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=600; total time=  12.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=700; total time=  14.2s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=800; total time=  16.5s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=900; total time=  19.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=1000; total time=  21.3s
# [CV] END bootstrap=True, max_depth=2, max_features=None, n_estimators=1000; total time=  21.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=400; total time=   4.4s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=500; total time=   5.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=500; total time=   5.7s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=600; total time=   6.9s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=700; total time=   7.6s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=800; total time=   8.5s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=900; total time=  10.0s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=900; total time=   9.9s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, n_estimators=1000; total time=  11.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=300; total time=   3.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=400; total time=   4.4s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=500; total time=   5.6s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=600; total time=   6.7s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=700; total time=   7.9s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=700; total time=   7.7s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=800; total time=   8.9s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=900; total time=  10.1s
# [CV] END bootstrap=True, max_depth=4, max_features=log2, n_estimators=1000; total time=  11.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=100; total time=   3.6s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=100; total time=   3.5s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=200; total time=   7.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=200; total time=   7.0s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=300; total time=  10.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=400; total time=  14.0s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=500; total time=  17.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=600; total time=  20.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=600; total time=  20.4s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=700; total time=  25.6s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=800; total time=  31.1s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=900; total time=  30.7s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=1000; total time=  34.2s
# [CV] END bootstrap=True, max_depth=4, max_features=None, n_estimators=1000; total time=  34.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=500; total time=   6.9s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=500; total time=   6.8s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=600; total time=   8.2s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=700; total time=   9.4s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=800; total time=  10.6s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=900; total time=  11.8s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=900; total time=  11.5s
# [CV] END bootstrap=True, max_depth=6, max_features=sqrt, n_estimators=1000; total time=  13.2s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=200; total time=   2.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=300; total time=   4.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=400; total time=   5.3s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=500; total time=   6.7s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=600; total time=   8.0s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=700; total time=   9.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=700; total time=   9.4s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=800; total time=  10.5s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=900; total time=  11.9s
# [CV] END bootstrap=True, max_depth=6, max_features=log2, n_estimators=1000; total time=  13.0s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=100; total time=   5.0s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=100; total time=   4.8s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=200; total time=   9.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=200; total time=   9.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=300; total time=  14.6s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=400; total time=  20.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=500; total time=  23.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=600; total time=  27.5s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=600; total time=  26.7s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=700; total time=  32.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=800; total time=  37.3s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=900; total time=  40.9s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=1000; total time=  46.1s
# [CV] END bootstrap=True, max_depth=6, max_features=None, n_estimators=1000; total time=  45.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=600; total time=   9.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=600; total time=   9.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=700; total time=  10.7s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=800; total time=  12.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=900; total time=  13.4s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  14.8s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=500; total time=   7.6s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=600; total time=   9.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=600; total time=   9.4s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=700; total time=  10.9s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=8, max_features=log2, n_estimators=1000; total time=  15.3s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=200; total time=  11.4s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=300; total time=  17.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=300; total time=  17.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=400; total time=  22.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=500; total time=  28.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=600; total time=  34.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=700; total time=  40.2s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=700; total time=  39.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=800; total time=  45.5s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=900; total time=  51.7s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=1000; total time=  57.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200; total time=   3.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=300; total time=   5.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400; total time=   7.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400; total time=   7.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=500; total time=   9.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=600; total time=  11.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=600; total time=  11.0s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=700; total time=  12.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=800; total time=  14.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=900; total time=  15.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  17.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  17.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=300; total time=   5.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=500; total time=   8.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=600; total time=  10.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=700; total time=  12.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=700; total time=  12.5s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=800; total time=  14.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=900; total time=  15.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=1000; total time=  17.1s
# GridSearchCV(cv=10, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [100, 200, 300, 400, 500, 600, 700,
#                                           800, 900, 1000]},
#              scoring=make_scorer(mean_squared_error, greater_is_better=False),
#              verbose=2)

# %%
print ('Best Parameters: ', rf_Grid.best_params_)
print("Best RMSE Score: ", rf_Grid.best_score_)
# Out:
# Best Parameters:  {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 400}
# Best RMSE Score:  -58549368.61814742

# %% [markdown]
# ## Using the best parameters

# %% [markdown]
# ### Randomized Search

# %%
start_time = time.time()

randmf = RandomForestRegressor(**rf_random.best_params_) 
randmf.fit(X_train, y_train) 

end_time = time.time()
all_rand_run_time = end_time - start_time

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_rand = randmf.predict(X_test)

plt.figure(figsize=(5, 7))

sns.kdeplot(y_test, color="r", label="Actual Value")
sns.kdeplot(y_pred_rand, color="b", label="Fitted Values")

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
plt.close()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np
y_train_rand_pred = randmf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_rand_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_rand_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse_all_rand = np.sqrt(mean_squared_error(y_test, y_pred_rand))
print("Root Mean Square Error (RMSE):", rmse_all_rand)

#MAPE
mape_all_rand = mean_absolute_percentage_error(y_test, y_pred_rand)
print(" Mean Absolute Percentage Error (MAPE):", mape_all_rand)
print()
AUC_all_rand = AUC(y_test, y_pred_rand)
#AUC
print("AUC test:", AUC_all_rand)
# Out:
# Test accuracy for train set
# Root Mean Square Error (RMSE): 496.96510970639497
# Mean Absolute Percentage Error (MAPE): 0.03593135985740493
#
# Test accuracy for test set
# Root Mean Square Error (RMSE): 3219.5345345737405
#  Mean Absolute Percentage Error (MAPE): 0.07386966100767439
#
# AUC test: 0.19444444444444445

# %% [markdown]
# ### Grid Search

# %%
start_time = time.time()

gridmf = RandomForestRegressor(**rf_Grid.best_params_) 
gridmf.fit(X_train, y_train) 

end_time = time.time()
all_grid_run_time = end_time - start_time

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_grid = gridmf.predict(X_test)

plt.figure(figsize=(5, 7))

sns.kdeplot(y_test, color="r", label="Actual Value")
sns.kdeplot(y_pred_grid, color="b", label="Fitted Values")

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
plt.close()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np

y_train_grid_pred = gridmf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_grid_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_grid_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse_all_grid = np.sqrt(mean_squared_error(y_test, y_pred_grid))
print("Root Mean Square Error (RMSE):", rmse_all_grid)

#MAPE
mape_all_grid = mean_absolute_percentage_error(y_test, y_pred_grid)
print(" Mean Absolute Percentage Error (MAPE):", mape_all_grid)
print()
AUC_all_grid = AUC(y_test, y_pred_grid)
#AUC
print("AUC test:", AUC_all_grid)
# Out:
# Test accuracy for train set
# Root Mean Square Error (RMSE): 496.96510970639497
# Mean Absolute Percentage Error (MAPE): 0.035931359857404935
#
# Test accuracy for test set
# Root Mean Square Error (RMSE): 3193.314289902959
#  Mean Absolute Percentage Error (MAPE): 0.07275058107787429
#
# AUC test: 0.18981481481481483

# %% [markdown]
# ## Feature Reduction

# %% [markdown]
# ### Randomized Search

# %%
features_rand = X_train.columns
# Get numerical feature importances
importances_rand = list(randmf.feature_importances_)
# List of tuples with variable and importance
feature_importances_rand = [(feature, round(importance, 4)) for feature, importance in zip(features_rand, importances_rand)]
# Sort the feature importances by most important first
feature_importances_rand = sorted(feature_importances_rand, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_rand]
# Out:
# Variable: BTC_close            Importance: 0.4644
# Variable: BTC_high             Importance: 0.3432
# Variable: BTC_low              Importance: 0.1907
# Variable: DOGE                 Importance: 0.0003
# Variable: BTC_open             Importance: 0.0002
# Variable: Mean_Block_Size(in_bytes) Importance: 0.0002
# Variable: Xfer_Cnt             Importance: 0.0002
# Variable: GOLD                 Importance: 0.0002
# Variable: Active_Addr_Cnt      Importance: 0.0001
# Variable: Mean_Hashrate        Importance: 0.0001
# Variable: ETH                  Importance: 0.0001
# Variable: LTC                  Importance: 0.0001
# Variable: JP225                Importance: 0.0001
# Variable: BTC_volume           Importance: 0.0
# Variable: Difficulty           Importance: 0.0
# Variable: Sum_Block_Weight     Importance: 0.0
# Variable: Total_Fees(USD)      Importance: 0.0
# Variable: Mean_Tx_size(native_units) Importance: 0.0
# Variable: XRP                  Importance: 0.0
# Variable: SILVER               Importance: 0.0
# Variable: COPPER               Importance: 0.0
# Variable: S&P500               Importance: 0.0
# Variable: DJI                  Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# list of x locations for plotting
x_values = list(range(len(importances_rand)))
# Make a bar chart
plt.bar(x_values, importances_rand, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)
# Tick labels for x axis
plt.xticks(x_values, features_rand, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# List of features sorted from most to least important
sorted_importances_rand = [importance[1] for importance in feature_importances_rand]
sorted_features_rand = [importance[0] for importance in feature_importances_rand]
# Cumulative importances
cumulative_importances_rand = np.cumsum(sorted_importances_rand)
# Make a line graph
plt.plot(x_values, cumulative_importances_rand, 'g-')
# Draw line at 95% of importance retained
plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances_rand), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(x_values, sorted_features_rand, rotation = 'vertical')
# Axis labels and title
plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');

# %%
# Find number of features for cumulative importance of 95%
# Add 1 because Python is zero-indexed
num_rand = np.where(cumulative_importances_rand > 0.95)[0][0] + 1
print('Number of features for 95% importance:', num_rand)
# Out:
# Number of features for 95% importance: 3

# %%
# Extract the names of the most important features
important_feature_names_rand = [feature[0] for feature in feature_importances_rand[0:num_rand]]
print(important_feature_names_rand)
# Out:
# ['BTC_close', 'BTC_high', 'BTC_low']

# %%
train_data_rand = X_train[important_feature_names_rand]
test_data_rand = X_test[important_feature_names_rand]
# Sanity check on operations
print('Important train features shape:', train_data_rand.shape)
print('Important test features shape:', test_data_rand.shape)
# Out:
# Important train features shape: (1944, 3)
# Important test features shape: (649, 3)

# %% [markdown]
# ### Grid Search

# %%
features_grid = X_train.columns
# Get numerical feature importances
importances_grid = list(gridmf.feature_importances_)
# List of tuples with variable and importance
feature_importances_grid = [(feature, round(importance, 4)) for feature, importance in zip(features_grid, importances_grid)]
# Sort the feature importances by most important first
feature_importances_grid = sorted(feature_importances_grid, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_grid]
# Out:
# Variable: BTC_close            Importance: 0.4356
# Variable: BTC_high             Importance: 0.4008
# Variable: BTC_low              Importance: 0.1619
# Variable: DOGE                 Importance: 0.0003
# Variable: BTC_open             Importance: 0.0002
# Variable: Mean_Block_Size(in_bytes) Importance: 0.0002
# Variable: Xfer_Cnt             Importance: 0.0002
# Variable: GOLD                 Importance: 0.0002
# Variable: Active_Addr_Cnt      Importance: 0.0001
# Variable: Mean_Hashrate        Importance: 0.0001
# Variable: ETH                  Importance: 0.0001
# Variable: LTC                  Importance: 0.0001
# Variable: JP225                Importance: 0.0001
# Variable: BTC_volume           Importance: 0.0
# Variable: Difficulty           Importance: 0.0
# Variable: Sum_Block_Weight     Importance: 0.0
# Variable: Total_Fees(USD)      Importance: 0.0
# Variable: Mean_Tx_size(native_units) Importance: 0.0
# Variable: XRP                  Importance: 0.0
# Variable: SILVER               Importance: 0.0
# Variable: COPPER               Importance: 0.0
# Variable: S&P500               Importance: 0.0
# Variable: DJI                  Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# list of x locations for plotting
x_values = list(range(len(importances_rand)))
# Make a bar chart
plt.bar(x_values, importances_rand, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)
# Tick labels for x axis
plt.xticks(x_values, features_rand, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# List of features sorted from most to least important
sorted_importances_grid = [importance[1] for importance in feature_importances_grid]
sorted_features_grid = [importance[0] for importance in feature_importances_grid]
# Cumulative importances
cumulative_importances_grid = np.cumsum(sorted_importances_grid)
# Make a line graph
plt.plot(x_values, cumulative_importances_grid, 'g-')
# Draw line at 95% of importance retained
plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances_grid), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(x_values, sorted_features_grid, rotation = 'vertical')
# Axis labels and title
plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');

# %%
# Find number of features for cumulative importance of 95%
# Add 1 because Python is zero-indexed
num_rand = np.where(cumulative_importances_rand > 0.95)[0][0] + 1
print('Number of features for 95% importance:', num_rand)
# Out:
# Number of features for 95% importance: 3

# %%
# Extract the names of the most important features
important_feature_names_grid = [feature[0] for feature in feature_importances_grid[0:num_rand]]
print(important_feature_names_grid)
# Out:
# ['BTC_close', 'BTC_high', 'BTC_low']

# %%
train_data_grid = X_train[important_feature_names_grid]
test_data_grid = X_test[important_feature_names_grid]
# Sanity check on operations
print('Important train features shape:', train_data_grid.shape)
print('Important test features shape:', test_data_grid.shape)
# Out:
# Important train features shape: (1944, 3)
# Important test features shape: (649, 3)

# %% [markdown]
# #### Training and Evaluating on Important Features

# %% [markdown]
# ### Randomized Search

# %%
start_time = time.time()

# Train the expanded model on only the important features
randmf.fit(train_data_rand, y_train);

# Make predictions on test data
predictions_rand = randmf.predict(test_data_rand)

end_time = time.time()
reduce_rand_run_time = end_time - start_time

#RMSE
from sklearn.metrics import mean_squared_error
rmse_reduce_rand = np.sqrt(mean_squared_error(y_test, predictions_rand))
print("RMSE:", rmse_reduce_rand)
print()

#MAPE
mape_reduce_rand = np.average(np.abs((y_test - predictions_rand) / y_test))
print("MAPE:", mape_reduce_rand)
print()

AUC_reduce_rand = AUC(np.array(y_test), predictions_rand)
print("AUC test:", AUC_reduce_rand )
# Out:
# RMSE: 2324.0293051478907
#
# MAPE: 0.05783269641929595
#
# AUC test: 0.18981481481481483

# %% [markdown]
# ### Grid Search

# %%
start_time = time.time()

# Train the expanded model on only the important features
gridmf.fit(train_data_grid, y_train);

# Make predictions on test data
predictions_grid = gridmf.predict(test_data_grid)

end_time = time.time()
reduce_grid_run_time = end_time - start_time

#RMSE
from sklearn.metrics import mean_squared_error
rmse_reduce_grid = np.sqrt(mean_squared_error(y_test, predictions_grid))
print("RMSE:", rmse_reduce_grid)
print()

#MAPE
mape_reduce_grid = np.average(np.abs((y_test - predictions_grid) / y_test))
print("MAPE:", mape_reduce_grid)
print()

AUC_reduce_grid = AUC(np.array(y_test), predictions_grid)
print("AUC test:", AUC_reduce_grid )
# Out:
# RMSE: 2320.508420046752
#
# MAPE: 0.05763987120048248
#
# AUC test: 0.18981481481481483

# %% [markdown]
# #### Normalization with original data

# %% [markdown]
# ### Randomized Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_all_rand = MinMaxScaler()
X_train_normalized_all_rand = scaler_all_rand.fit_transform(X_train)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_all_rand = scaler_all_rand.transform(X_test)

# %%
rf_regressor_all_rand = RandomForestRegressor(**rf_random.best_params_)

start_time = time.time()

rf_regressor_all_rand.fit(X_train_normalized_all_rand, y_train)

y_pred_norma_all_rand = rf_regressor_all_rand.predict(X_test_normalized_all_rand)

end_time = time.time()
normal_all_rand_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_all_rand = np.sqrt(mean_squared_error(y_test, y_pred_norma_all_rand))
print("RMSE:", rmse_normal_all_rand)
print()

#MAPE
mape_normal_all_rand = np.average(np.abs((y_test - y_pred_norma_all_rand) / y_test))
print("MAPE:", mape_normal_all_rand)
print()

AUC_normal_all_rand = AUC(np.array(y_test), y_pred_norma_all_rand)
print("AUC test:", AUC_normal_all_rand )
# Out:
# RMSE: 3200.6655843742287
#
# MAPE: 0.07232997952855776
#
# AUC test: 0.19444444444444445

# %% [markdown]
# ### Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_all_grid = MinMaxScaler()
X_train_normalized_all_grid = scaler_all_grid.fit_transform(X_train)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_all_grid = scaler_all_grid.transform(X_test)

# %%
rf_regressor_all_grid = RandomForestRegressor(**rf_Grid.best_params_)

start_time = time.time()

rf_regressor_all_grid.fit(X_train_normalized_all_grid, y_train)

y_pred_norma_all_grid = rf_regressor_all_grid.predict(X_test_normalized_all_grid)

end_time = time.time()
normal_all_grid_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_all_grid = np.sqrt(mean_squared_error(y_test, y_pred_norma_all_grid))
print("RMSE:", rmse_normal_all_rand)
print()

#MAPE
mape_normal_all_grid = np.average(np.abs((y_test - y_pred_norma_all_grid) / y_test))
print("MAPE:", mape_normal_all_grid)
print()

AUC_normal_all_grid = AUC(np.array(y_test), y_pred_norma_all_grid)
print("AUC test:", AUC_normal_all_grid )
# Out:
# RMSE: 3200.6655843742287
#
# MAPE: 0.07277027269523896
#
# AUC test: 0.19444444444444445

# %% [markdown]
# #### Normalization with Importance Features

# %% [markdown]
# ### Radomized Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_reduce_rand = MinMaxScaler()
X_train_normalized_reduce_rand = scaler_reduce_rand.fit_transform(train_data_rand)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_reduce_rand = scaler_reduce_rand.transform(test_data_rand)

# %%
rf_regressor_reduce_rand = RandomForestRegressor(**rf_random.best_params_)

start_time = time.time()
rf_regressor_reduce_rand.fit(X_train_normalized_reduce_rand, y_train)

y_pred_norma_reduce_rand = rf_regressor_reduce_rand.predict(X_test_normalized_reduce_rand)

end_time = time.time()
normal_reduce_rand_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_reduce_rand = np.sqrt(mean_squared_error(y_test, y_pred_norma_reduce_rand))
print("RMSE:", rmse_normal_reduce_rand)
print()

#MAPE
mape_normal_reduce_rand = np.average(np.abs((y_test - y_pred_norma_reduce_rand) / y_test))
print("MAPE:", mape_normal_reduce_rand)
print()

AUC_normal_reduce_rand = AUC(np.array(y_test), y_pred_norma_reduce_rand)
print("AUC test:", AUC_normal_reduce_rand)
# Out:
# RMSE: 2322.605178322074
#
# MAPE: 0.057740830746814686
#
# AUC test: 0.18981481481481483

# %% [markdown]
# ### Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_grid = MinMaxScaler()
X_train_normalized_reduce_grid = scaler_grid.fit_transform(train_data_grid)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_reduce_grid = scaler_grid.transform(test_data_grid)

# %%
rf_regressor_reduce_grid = RandomForestRegressor(**rf_Grid.best_params_)

start_time = time.time()
rf_regressor_reduce_grid.fit(X_train_normalized_reduce_grid, y_train)

y_pred_norma_reduce_grid = rf_regressor_reduce_grid.predict(X_test_normalized_reduce_grid)

end_time = time.time()
normal_reduce_grid_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_reduce_grid = np.sqrt(mean_squared_error(y_test, y_pred_norma_reduce_grid))
print("RMSE:", rmse_normal_reduce_grid)
print()

#MAPE
mape_normal_reduce_grid = np.average(np.abs((y_test - y_pred_norma_reduce_grid) / y_test))
print("MAPE:", mape_normal_reduce_rand)
print()

AUC_normal_reduce_grid = AUC(np.array(y_test), y_pred_norma_reduce_grid)
print("AUC test:", AUC_normal_reduce_grid)
# Out:
# RMSE: 2320.403744211343
#
# MAPE: 0.057740830746814686
#
# AUC test: 0.18981481481481483

# %% [markdown]
# ## Summary statistical table

# %% [markdown]
# ### Randomized Search

# %%
def print_results_rand(AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time, 
                       AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time, 
                  AUC_normal_all_rand, rmse_normal_all_rand, mape_normal_all_rand, normal_all_rand_run_time,
                 AUC_normal_reduce_rand, rmse_normal_reduce_rand, mape_normal_reduce_rand, normal_reduce_rand_run_time):
    headers = ['Type', 'Number of Features','Accuracy', 'RMSE', 'MAPE', 'Run Time (s)']
    all_results = [['All', len(importances_rand), AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time],
                   ['Reduce', len(important_feature_names_rand), AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time],
                   ['Normalization - All', len(importances_rand), AUC_normal_all_rand, rmse_normal_all_rand, mape_normal_all_rand, normal_all_rand_run_time],
                  ['Normalization - Reduce', len(important_feature_names_rand), AUC_normal_reduce_rand, rmse_normal_reduce_rand, mape_normal_reduce_rand, normal_reduce_rand_run_time]]

    # Calculate the maximum width for each column
    col_widths = [max(len(str(row[i])) for row in all_results + [headers]) for i in range(len(headers))]

    # Print table headers
    header_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    print(header_format.format(*headers))

    # Print separator row
    separator = '-' * (sum(col_widths) + 3 * (len(col_widths) - 1))
    print(separator)

    # Print table rows
    row_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    for result in all_results:
        index, num_features, AUC, rmse, mape, run_time = result
        print(row_format.format(index, num_features, AUC, rmse, mape, run_time))
        
print_results_rand(AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time, 
                       AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time, 
                  AUC_normal_all_rand, rmse_normal_all_rand, mape_normal_all_rand, normal_all_rand_run_time,
                 AUC_normal_reduce_rand, rmse_normal_reduce_rand, mape_normal_reduce_rand, normal_reduce_rand_run_time)
# Out:
# Type                    Number of Features  Accuracy             RMSE                MAPE                  Run Time (s)
# ----------------------------------------------------------------------------------------------------------------------------------
# All                     23                  0.19444444444444445  3219.5345345737405  0.07386966100767439   11.012859106063843
# Reduce                  3                   0.18981481481481483  2324.0293051478907  0.05783269641929595   2.2958321571350098
# Normalization - All     23                  0.19444444444444445  3200.6655843742287  0.07232997952855776   11.56830096244812
# Normalization - Reduce  3                   0.18981481481481483  2322.605178322074   0.057740830746814686  2.4068589210510254

# %% [markdown]
# ### Grid Search

# %%
def print_results_rand(AUC_all_grid, rmse_all_grid, mape_all_grid, all_grid_run_time, 
                       AUC_reduce_grid, rmse_reduce_grid, mape_reduce_grid, reduce_grid_run_time, 
                  AUC_normal_all_grid, rmse_normal_all_grid, mape_normal_all_grid, normal_all_grid_run_time,
                 AUC_normal_reduce_grid, rmse_normal_reduce_grid, mape_normal_reduce_grid, normal_reduce_grid_run_time):
    headers = ['Type', 'Number of Features','Accuracy', 'RMSE', 'MAPE', 'Run Time (s)']
    all_results = [['All', len(importances_grid), AUC_all_grid, rmse_all_grid, mape_all_grid, all_grid_run_time],
                   ['Reduce', len(important_feature_names_grid), AUC_reduce_grid, rmse_reduce_grid, mape_reduce_grid, reduce_grid_run_time],
                   ['Normalization - All', len(importances_grid), AUC_normal_all_grid, rmse_normal_all_grid, mape_normal_all_grid, normal_all_grid_run_time],
                  ['Normalization - Reduce', len(important_feature_names_grid), AUC_normal_reduce_grid, rmse_normal_reduce_grid, mape_normal_reduce_grid, normal_reduce_grid_run_time]]

    # Calculate the maximum width for each column
    col_widths = [max(len(str(row[i])) for row in all_results + [headers]) for i in range(len(headers))]

    # Print table headers
    header_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    print(header_format.format(*headers))

    # Print separator row
    separator = '-' * (sum(col_widths) + 3 * (len(col_widths) - 1))
    print(separator)

    # Print table rows
    row_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    for result in all_results:
        index, num_features, AUC, rmse, mape, run_time = result
        print(row_format.format(index, num_features, AUC, rmse, mape, run_time))
        
print_results_rand(AUC_all_grid, rmse_all_grid, mape_all_grid, all_grid_run_time, 
                       AUC_reduce_grid, rmse_reduce_grid, mape_reduce_grid, reduce_grid_run_time, 
                  AUC_normal_all_grid, rmse_normal_all_grid, mape_normal_all_grid, normal_all_grid_run_time,
                 AUC_normal_reduce_grid, rmse_normal_reduce_grid, mape_normal_reduce_grid, normal_reduce_grid_run_time)
# Out:
# Type                    Number of Features  Accuracy             RMSE                MAPE                 Run Time (s)
# ---------------------------------------------------------------------------------------------------------------------------------
# All                     23                  0.18981481481481483  3193.314289902959   0.07275058107787429  10.955623865127563
# Reduce                  3                   0.18981481481481483  2320.508420046752   0.05763987120048248  2.2906360626220703
# Normalization - All     23                  0.19444444444444445  3188.6359087216933  0.07277027269523896  11.782701015472412
# Normalization - Reduce  3                   0.18981481481481483  2320.403744211343   0.05766967935465719  2.385590076446533

# %% [markdown]
# # Graph Predicted Values with Test Set

# %% [markdown]
# ### Randomized Search

# %%
#hien thi ket qua du doan
fig, ax = plt.subplots(1, 1, figsize=(14, 5))
ax.plot(y_test, color = 'red', label="Bitcoin Price")
ax.plot(y_pred_rand, color = 'green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))  # .3f
plt.title("Random Forest Regression for Period 2")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 5))

ax.plot(total['Date'], total['BTC_close'], color='red', label="Bitcoin Price")
ax.plot(total['Date'][:len(y_train)], y_train, color='blue', label="Training Data")
ax.plot(total['Date'][-len(y_test):], y_test, color='orange', label="Test Data")
ax.plot(total['Date'][-len(y_pred):], y_pred_rand, color='green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # Định dạng đường trục y
plt.legend()
plt.show()

# %% [markdown]
# ### Grid Search

# %%
#hien thi ket qua du doan
fig, ax = plt.subplots(1, 1, figsize=(14, 5))
ax.plot(y_test, color = 'red', label="Bitcoin Price")
ax.plot(y_pred_grid, color = 'green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))  # .3f
plt.title("Random Forest Regression for Period 2")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 5))

ax.plot(total['Date'], total['BTC_close'], color='red', label="Bitcoin Price")
ax.plot(total['Date'][:len(y_train)], y_train, color='blue', label="Training Data")
ax.plot(total['Date'][-len(y_test):], y_test, color='orange', label="Test Data")
ax.plot(total['Date'][-len(y_pred):], y_pred_grid, color='green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # Định dạng đường trục y
plt.legend()
plt.show()
# Out:
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=900; total time=  15.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  17.2s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200; total time=   3.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200; total time=   3.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=300; total time=   5.2s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=500; total time=   8.9s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=500; total time=   8.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=600; total time=  11.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=700; total time=  12.6s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=800; total time=  14.2s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=900; total time=  15.9s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=900; total time=  15.3s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=1000; total time=  17.4s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=100; total time=   7.0s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=200; total time=  13.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=300; total time=  20.3s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=400; total time=  27.4s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=400; total time=  25.8s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=500; total time=  33.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=600; total time=  40.8s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=700; total time=  47.2s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=800; total time=  54.9s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=800; total time=  54.1s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=900; total time= 1.0min
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=1000; total time=  55.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   1.3s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   1.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=500; total time=   2.4s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=600; total time=   2.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=700; total time=   3.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=700; total time=   3.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=800; total time=   3.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=900; total time=   5.0s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=1000; total time=   4.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=300; total time=   1.4s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=400; total time=   1.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=500; total time=   2.5s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=600; total time=   2.8s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=700; total time=   3.4s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=800; total time=   4.0s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=900; total time=   4.1s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=900; total time=   4.2s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=1000; total time=   5.0s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=300; total time=   5.6s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=400; total time=   7.2s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=400; total time=   7.0s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=500; total time=   8.4s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=   9.2s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=700; total time=  10.3s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=800; total time=  13.5s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=800; total time=  13.2s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=900; total time=  15.2s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=1000; total time=  16.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=500; total time=   3.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=600; total time=   4.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=700; total time=   4.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=800; total time=   5.7s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=800; total time=   6.6s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=900; total time=   6.9s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=1000; total time=   7.5s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=200; total time=   1.5s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=500; total time=   3.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=600; total time=   3.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=   4.6s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=   4.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=800; total time=   5.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=900; total time=   6.2s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=1000; total time=   7.4s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=300; total time=   8.8s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  11.7s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=500; total time=  13.5s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=600; total time=  16.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=700; total time=  19.2s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=700; total time=  17.5s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=800; total time=  20.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=900; total time=  23.3s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=1000; total time=  29.2s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=700; total time=   6.1s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=800; total time=   7.3s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=800; total time=   7.6s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=900; total time=   8.2s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=1000; total time=   9.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=500; total time=   4.5s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=600; total time=   5.4s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=   6.3s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=800; total time=   7.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=900; total time=   9.7s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=1000; total time=  10.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=1000; total time=  11.1s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=200; total time=   8.7s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=300; total time=  11.3s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=300; total time=  18.7s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  18.9s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=500; total time=  22.6s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=600; total time=  25.3s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=700; total time=  29.4s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=700; total time=  33.1s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=800; total time=  35.4s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=900; total time=  41.2s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=1000; total time=  46.6s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=100; total time=   1.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=300; total time=   3.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=300; total time=   3.8s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=400; total time=   4.9s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=400; total time=   3.9s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=500; total time=   4.9s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=600; total time=   6.0s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=700; total time=   7.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=700; total time=   7.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=800; total time=   8.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=900; total time=   9.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  10.1s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=400; total time=   3.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=400; total time=   4.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=500; total time=   4.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=600; total time=   5.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=700; total time=   6.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=800; total time=   7.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=800; total time=   7.7s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=900; total time=   8.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=1000; total time=   9.8s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=200; total time=   8.7s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=300; total time=  15.3s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=400; total time=  19.3s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=500; total time=  28.0s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=500; total time=  25.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=600; total time=  27.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=700; total time=  31.7s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=800; total time=  35.0s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=900; total time=  39.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=900; total time=  51.7s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=1000; total time=  49.7s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400; total time=   5.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=500; total time=   7.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=600; total time=   8.8s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=600; total time=   8.8s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=700; total time=  10.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=900; total time=  17.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  20.8s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  28.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=  12.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=  13.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  12.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=   8.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=   9.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  11.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  12.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  14.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  13.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=  18.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  22.6s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  25.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  19.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=400; total time=  23.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=500; total time=  31.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=600; total time=  39.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=700; total time=  39.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=700; total time=  43.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=800; total time=  52.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=900; total time=  58.3s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=1000; total time= 1.1min
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=200; total time=  13.4s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=300; total time=  20.4s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=400; total time=  27.2s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=500; total time=  33.2s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=500; total time=  33.7s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=600; total time=  41.0s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=700; total time=  46.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=800; total time=  55.0s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=900; total time= 1.0min
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=900; total time= 1.0min
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=1000; total time=  47.9s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=700; total time=   3.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=800; total time=   3.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=800; total time=   4.1s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=900; total time=   4.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=1000; total time=   4.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=100; total time=   0.5s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=200; total time=   1.0s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=300; total time=   1.4s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=400; total time=   1.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=500; total time=   2.5s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=500; total time=   2.2s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=600; total time=   2.8s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=700; total time=   3.3s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=800; total time=   4.1s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=900; total time=   4.1s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=900; total time=   4.2s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=1000; total time=   5.0s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=300; total time=   5.6s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=500; total time=   8.4s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=   9.2s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=700; total time=  10.3s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=800; total time=  13.4s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=800; total time=  13.2s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=900; total time=  15.1s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=1000; total time=  16.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=500; total time=   3.5s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=500; total time=   3.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=600; total time=   4.3s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=700; total time=   4.7s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=800; total time=   6.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=900; total time=   7.2s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=900; total time=   6.7s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=1000; total time=   7.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=300; total time=   2.0s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=500; total time=   3.2s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=600; total time=   3.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=   4.7s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=   4.7s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=800; total time=   5.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=900; total time=   6.2s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=1000; total time=   7.4s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=100; total time=   3.1s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=300; total time=   8.8s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=500; total time=  13.5s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=600; total time=  16.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=700; total time=  19.1s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=700; total time=  17.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=800; total time=  20.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=900; total time=  23.5s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=1000; total time=  29.2s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   1.7s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=300; total time=   2.6s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=600; total time=   5.2s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=700; total time=   6.1s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=800; total time=   7.4s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=900; total time=   8.6s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=900; total time=   8.0s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=1000; total time=   9.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=500; total time=   4.5s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=   6.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=800; total time=   7.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=900; total time=   9.6s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=900; total time=   9.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=1000; total time=  10.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=200; total time=   8.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=300; total time=  11.1s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  25.4s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  15.8s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=500; total time=  23.2s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=600; total time=  25.0s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=700; total time=  30.0s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=800; total time=  38.4s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=800; total time=  35.8s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=900; total time=  39.6s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=1000; total time=  46.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=300; total time=   3.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=400; total time=   3.9s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=500; total time=   4.9s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=600; total time=   6.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=600; total time=   6.0s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=700; total time=   7.0s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=800; total time=   8.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=900; total time=   9.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  10.4s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=1000; total time=   9.7s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=400; total time=   3.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=500; total time=   5.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=600; total time=   5.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=600; total time=   5.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=700; total time=   6.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=800; total time=   7.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=900; total time=   8.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=1000; total time=   9.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=1000; total time=   9.8s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=200; total time=   8.7s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=200; total time=   8.7s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=300; total time=  15.7s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=400; total time=  19.2s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=500; total time=  28.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=600; total time=  30.3s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=600; total time=  27.2s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=700; total time=  31.2s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=800; total time=  35.3s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=900; total time=  42.5s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=1000; total time=  53.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=1000; total time=  51.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=700; total time=  10.4s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=800; total time=  11.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=900; total time=  17.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=900; total time=  17.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  24.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   8.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=  12.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=  11.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=  11.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  10.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=   9.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  10.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=   9.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  10.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  14.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  14.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   6.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=  16.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  24.1s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  26.1s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  19.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=400; total time=  23.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=500; total time=  31.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=600; total time=  40.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=700; total time=  39.1s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=700; total time=  44.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=800; total time=  52.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=900; total time=  58.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=1000; total time= 1.1min
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=900; total time=  50.9s
# [CV] END bootstrap=True, max_depth=8, max_features=None, n_estimators=1000; total time=  58.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=200; total time=   3.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=300; total time=   5.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400; total time=   7.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=400; total time=   7.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=500; total time=   9.3s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=600; total time=  11.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=700; total time=  12.6s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=800; total time=  14.5s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=800; total time=  14.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=900; total time=  15.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  17.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200; total time=   3.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=200; total time=   3.4s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=300; total time=   5.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=400; total time=   7.2s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=500; total time=   8.9s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=500; total time=   8.8s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=600; total time=  11.1s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=700; total time=  12.5s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=800; total time=  14.2s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=900; total time=  16.0s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=900; total time=  15.3s
# [CV] END bootstrap=True, max_depth=10, max_features=log2, n_estimators=1000; total time=  17.4s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=100; total time=   7.0s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=200; total time=  13.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=300; total time=  20.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=400; total time=  27.4s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=400; total time=  26.2s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=500; total time=  33.5s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=600; total time=  41.1s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=700; total time=  47.0s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=800; total time=  54.9s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=800; total time=  52.9s
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=900; total time= 1.0min
# [CV] END bootstrap=True, max_depth=10, max_features=None, n_estimators=1000; total time=  55.5s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   1.3s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=300; total time=   1.6s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=400; total time=   1.9s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=400; total time=   1.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=500; total time=   2.4s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=700; total time=   3.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=700; total time=   3.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=800; total time=   3.7s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=900; total time=   4.8s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=1000; total time=   5.2s
# [CV] END bootstrap=False, max_depth=2, max_features=sqrt, n_estimators=1000; total time=   4.6s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=300; total time=   1.3s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=400; total time=   1.9s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=400; total time=   2.0s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=500; total time=   2.3s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=600; total time=   2.7s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=700; total time=   3.4s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=800; total time=   4.0s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=800; total time=   3.7s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=900; total time=   4.2s
# [CV] END bootstrap=False, max_depth=2, max_features=log2, n_estimators=1000; total time=   4.9s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=400; total time=   7.1s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=500; total time=   8.8s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=500; total time=   8.4s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=700; total time=  10.3s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=800; total time=  13.6s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=900; total time=  15.3s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=900; total time=  14.5s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=1000; total time=  16.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=500; total time=   3.4s
# ...
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=500; total time=   8.6s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=   9.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=600; total time=   8.8s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=700; total time=  10.7s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=800; total time=  13.8s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=900; total time=  15.0s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=1000; total time=  16.1s
# [CV] END bootstrap=False, max_depth=2, max_features=None, n_estimators=1000; total time=  15.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=400; total time=   2.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=500; total time=   3.4s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=600; total time=   4.0s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=700; total time=   5.0s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=700; total time=   4.8s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=800; total time=   6.5s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=900; total time=   7.0s
# [CV] END bootstrap=False, max_depth=4, max_features=sqrt, n_estimators=1000; total time=   7.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=100; total time=   0.8s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=100; total time=   0.7s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=300; total time=   2.1s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=500; total time=   3.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=500; total time=   3.2s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=600; total time=   3.9s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=700; total time=   4.6s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=800; total time=   5.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=900; total time=   6.3s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=900; total time=   6.4s
# [CV] END bootstrap=False, max_depth=4, max_features=log2, n_estimators=1000; total time=   7.4s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=100; total time=   2.9s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=200; total time=   6.0s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=300; total time=   8.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  11.8s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=400; total time=  11.4s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=500; total time=  13.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=600; total time=  16.7s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=700; total time=  18.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=800; total time=  20.3s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=800; total time=  20.7s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=900; total time=  23.6s
# [CV] END bootstrap=False, max_depth=4, max_features=None, n_estimators=1000; total time=  29.3s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=200; total time=   1.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=300; total time=   2.7s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=400; total time=   3.6s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=500; total time=   4.4s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=700; total time=   6.1s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=700; total time=   6.3s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=800; total time=   7.4s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=900; total time=   8.6s
# [CV] END bootstrap=False, max_depth=6, max_features=sqrt, n_estimators=1000; total time=   9.0s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=100; total time=   0.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=200; total time=   1.9s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=300; total time=   2.8s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=400; total time=   3.7s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=500; total time=   4.6s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=500; total time=   4.5s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=600; total time=   5.3s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=700; total time=   6.2s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=800; total time=   7.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=900; total time=   9.5s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=900; total time=   9.1s
# [CV] END bootstrap=False, max_depth=6, max_features=log2, n_estimators=1000; total time=  10.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=100; total time=   4.7s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=200; total time=   8.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=300; total time=  11.2s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  25.5s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=400; total time=  15.6s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=500; total time=  23.3s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=600; total time=  24.8s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=700; total time=  30.1s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=800; total time=  38.3s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=800; total time=  36.4s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=900; total time=  39.7s
# [CV] END bootstrap=False, max_depth=6, max_features=None, n_estimators=1000; total time=  46.6s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=300; total time=   3.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=300; total time=   3.8s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=400; total time=   4.7s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=400; total time=   3.9s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=500; total time=   4.8s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=600; total time=   6.0s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=700; total time=   7.3s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=700; total time=   7.0s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=800; total time=   8.2s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=900; total time=   9.1s
# [CV] END bootstrap=False, max_depth=8, max_features=sqrt, n_estimators=1000; total time=  10.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=100; total time=   1.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=200; total time=   2.0s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=300; total time=   2.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=400; total time=   3.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=500; total time=   5.1s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=500; total time=   4.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=600; total time=   5.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=700; total time=   6.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=800; total time=   7.8s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=900; total time=   8.9s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=900; total time=   8.7s
# [CV] END bootstrap=False, max_depth=8, max_features=log2, n_estimators=1000; total time=   9.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=100; total time=   4.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=200; total time=   8.8s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=300; total time=  14.8s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=400; total time=  19.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=400; total time=  20.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=500; total time=  28.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=600; total time=  27.5s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=700; total time=  31.9s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=800; total time=  35.0s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=800; total time=  34.8s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=900; total time=  49.4s
# [CV] END bootstrap=False, max_depth=8, max_features=None, n_estimators=1000; total time=  50.9s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=200; total time=   2.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=300; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=300; total time=   3.7s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=400; total time=   5.1s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=700; total time=  10.3s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=800; total time=  12.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=900; total time=  17.5s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  21.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   7.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   8.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=  11.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=  13.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  12.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  10.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=   9.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  11.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  13.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  15.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  19.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  28.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  17.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  22.3s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=400; total time=  24.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=500; total time=  30.3s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=600; total time=  41.6s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=600; total time=  33.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=700; total time=  41.1s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=800; total time=  53.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=900; total time= 1.0min
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=1000; total time= 1.1min
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=1000; total time=  51.4s

# %% [markdown]
# ## Comparing randomized search and grid search for hyperparameter estimation

# %%
import numpy as np

from time import time
import scipy.stats as stats
from sklearn.utils.fixes import loguniform

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.datasets import load_digits
from sklearn.linear_model import SGDClassifier


# Utility function to report best scores
def report(results, n_top=10):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results["rank_test_score"] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print(
                "Mean validation score: {0:.3f} (std: {1:.3f})".format(
                    results["mean_test_score"][candidate],
                    results["std_test_score"][candidate],
                )
            )
            print("Parameters: {0}".format(results["params"][candidate]))
            print("")

# %% [markdown]
# #### Randomized Search

# %%
print((len(rf_random.cv_results_["params"])))
report(rf_random.cv_results_)
# Out:
# 10
# Model with rank: 1
# Mean validation score: -58829650.501 (std: 174263157.967)
# Parameters: {'n_estimators': 400, 'max_features': None, 'max_depth': 6, 'bootstrap': False}
#
# Model with rank: 2
# Mean validation score: -59086709.931 (std: 173173313.316)
# Parameters: {'n_estimators': 400, 'max_features': None, 'max_depth': 4, 'bootstrap': False}
#
# Model with rank: 3
# Mean validation score: -59212542.211 (std: 175295995.465)
# Parameters: {'n_estimators': 700, 'max_features': None, 'max_depth': 8, 'bootstrap': False}
#
# Model with rank: 4
# Mean validation score: -60293709.564 (std: 178105242.737)
# Parameters: {'n_estimators': 700, 'max_features': 'log2', 'max_depth': 6, 'bootstrap': False}
#
# Model with rank: 5
# Mean validation score: -61135967.452 (std: 180580688.949)
# Parameters: {'n_estimators': 1000, 'max_features': 'log2', 'max_depth': 8, 'bootstrap': True}
#
# Model with rank: 6
# Mean validation score: -65346901.613 (std: 192340783.940)
# Parameters: {'n_estimators': 700, 'max_features': 'log2', 'max_depth': 4, 'bootstrap': False}
#
# Model with rank: 7
# Mean validation score: -98117814.860 (std: 266645029.119)
# Parameters: {'n_estimators': 600, 'max_features': None, 'max_depth': 2, 'bootstrap': False}
#
# Model with rank: 8
# Mean validation score: -98405302.095 (std: 283830585.490)
# Parameters: {'n_estimators': 600, 'max_features': 'sqrt', 'max_depth': 2, 'bootstrap': True}
#
# Model with rank: 9
# Mean validation score: -99518231.061 (std: 286961709.314)
# Parameters: {'n_estimators': 1000, 'max_features': 'sqrt', 'max_depth': 2, 'bootstrap': True}
#
# Model with rank: 10
# Mean validation score: -100864270.640 (std: 290357754.480)
# Parameters: {'n_estimators': 300, 'max_features': 'sqrt', 'max_depth': 2, 'bootstrap': False}

# %% [markdown]
# #### Grid Search

# %%
print((len(rf_Grid.cv_results_["params"])))
report(rf_Grid.cv_results_)
# Out:
# 300
# Model with rank: 1
# Mean validation score: -58549368.618 (std: 173416971.640)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 400}
#
# Model with rank: 2
# Mean validation score: -58654883.819 (std: 173673750.865)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 500}
#
# Model with rank: 3
# Mean validation score: -58673141.312 (std: 173771178.506)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 900}
#
# Model with rank: 4
# Mean validation score: -58709696.819 (std: 173953462.267)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 200}
#
# Model with rank: 5
# Mean validation score: -58719434.079 (std: 173936075.109)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 1000}
#
# Model with rank: 6
# Mean validation score: -58756928.718 (std: 174050069.932)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 600}
#
# Model with rank: 7
# Mean validation score: -58785394.905 (std: 174031173.035)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 300}
#
# Model with rank: 8
# Mean validation score: -58787441.160 (std: 174091495.899)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 700}
#
# Model with rank: 9
# Mean validation score: -58797337.652 (std: 174163502.236)
# Parameters: {'bootstrap': False, 'max_depth': 6, 'max_features': None, 'n_estimators': 800}
#
# Model with rank: 10
# Mean validation score: -58841259.887 (std: 173186244.718)
# Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': None, 'n_estimators': 400}

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, date
import seaborn as sns

# %% [markdown]
# # Load Data
# * Handle missing values, duplicated values, outlier

# %%
total = pd.read_csv("/Users/ibulmnie/Documents/GitHub/ML20222.PredictionBitcoin/data/saved_data.csv")
total['Date'] = pd.to_datetime(total['Date'])

df = total.set_index('Date')
df.head()
# Out:
#             BTC_close  BTC_open  BTC_high  BTC_low  BTC_volume
# Date
# 2023-04-16    30310.3   30299.2   30545.3  30134.6       34.48  \
# 2023-04-15    30299.6   30472.6   30586.5  30208.8       31.71
# 2023-04-14    30472.5   30387.4   30964.9  30026.0       98.38
# 2023-04-13    30387.4   29892.4   30524.1  29864.5       65.87
# 2023-04-12    29886.4   30209.8   30473.0  29679.5       78.69
#
#             Active_Addr_Cnt    Difficulty  Mean_Block_Size(in_bytes)
# Date
# 2023-04-16         840992.0  4.788780e+13                1866594.290  \
# 2023-04-15        1045660.0  4.788780e+13                1839875.354
# 2023-04-14        1016042.0  4.788780e+13                1759535.436
# 2023-04-13        1009669.0  4.788780e+13                1812112.549
# 2023-04-12        1056542.0  4.788780e+13                1933495.919
#
#             Sum_Block_Weight  Total_Fees(USD)  ...      ETH     LTC      DOGE
# Date                                           ...
# 2023-04-16       495223185.0    484205.915377  ...  2119.29  100.03  0.090465  \
# 2023-04-15       631025193.0    630623.285367  ...  2090.59   96.66  0.088890
# 2023-04-14       559166432.0    858535.297189  ...  2099.98   96.34  0.088707
# 2023-04-13       567094231.0    767012.808110  ...  2012.11   94.19  0.087344
# 2023-04-12       635037442.0    757368.783682  ...  1916.58   92.02  0.083398
#
#                 XRP    GOLD  SILVER  COPPER   S&P500       DJI     JP225
# Date
# 2023-04-16  0.52089  2015.6  25.438  9023.5  4137.64  33885.31  28493.47
# 2023-04-15  0.51930  2002.2  25.460  9023.5  4137.64  33885.31  28493.47
# 2023-04-14  0.52269  2002.2  25.460  9023.5  4137.64  33885.31  28493.47
# 2023-04-13  0.51244  2041.3  25.925  9058.5  4146.22  34030.34  28156.97
# 2023-04-12  0.50473  2010.9  25.458  8916.5  4091.95  33647.22  28082.70
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (4654, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4654 entries, 2023-04-16 to 2010-07-20
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BTC_close                   4654 non-null   float64
#  1   BTC_open                    4654 non-null   float64
#  2   BTC_high                    4654 non-null   float64
#  3   BTC_low                     4654 non-null   float64
#  4   BTC_volume                  4654 non-null   float64
#  5   Active_Addr_Cnt             4654 non-null   float64
#  6   Difficulty                  4654 non-null   float64
#  7   Mean_Block_Size(in_bytes)   4654 non-null   float64
#  8   Sum_Block_Weight            4654 non-null   float64
#  9   Total_Fees(USD)             4654 non-null   float64
#  10  Mean_Hashrate               4654 non-null   float64
#  11  Xfer_Cnt                    4654 non-null   float64
#  12  Mean_Tx_size(native_units)  4654 non-null   float64
#  13  ETH                         4654 non-null   float64
#  14  LTC                         4654 non-null   float64
#  15  DOGE                        4654 non-null   float64
#  16  XRP                         4654 non-null   float64
#  17  GOLD                        4654 non-null   float64
#  18  SILVER                      4654 non-null   float64
#  19  COPPER                      4654 non-null   float64
#  20  S&P500                      4654 non-null   float64
#  21  DJI                         4654 non-null   float64
#  22  JP225                       4654 non-null   float64
# dtypes: float64(23)
# memory usage: 872.6 KB

# %%
df.describe()
# Out:
#           BTC_close      BTC_open      BTC_high       BTC_low   BTC_volume
# count   4654.000000   4654.000000   4654.000000   4654.000000  4654.000000  \
# mean    8950.828126   8944.396197   9182.648904   8680.543532   144.272183
# std    14517.759120  14515.100053  14900.138248  14078.916437   199.685947
# min        0.100000      0.100000      0.100000      0.000000     0.170000
# 25%      140.475000    140.400000    145.800000    135.825000    25.407500
# 50%      916.050000    915.050000    934.150000    877.350000    63.605000
# 75%     9932.450000   9926.450000  10231.950000   9636.050000   158.375000
# max    67527.900000  67528.700000  68990.600000  66334.900000   999.530000
#
#        Active_Addr_Cnt    Difficulty  Mean_Block_Size(in_bytes)
# count     4.654000e+03  4.654000e+03               4.654000e+03  \
# mean      4.974545e+05  7.399910e+12               6.883463e+05
# std       3.731797e+05  1.103629e+13               4.990862e+05
# min       4.080000e+02  1.820000e+02               4.164167e+02
# 25%       8.702175e+04  1.322172e+08               1.656955e+05
# 50%       5.389900e+05  2.840750e+11               7.887917e+05
# 75%       8.174050e+05  1.389755e+13               1.087807e+06
# max       1.366494e+06  4.788780e+13               2.535436e+06
#
#        Sum_Block_Weight  Total_Fees(USD)  ...          ETH          LTC
# count      4.654000e+03     4.654000e+03  ...  4654.000000  4654.000000  \
# mean       3.329426e+08     5.498044e+05  ...   505.010290    45.052975
# std        2.151278e+08     1.528054e+06  ...   945.449318    63.364718
# min        2.841400e+05     0.000000e+00  ...     0.000000     0.000000
# 25%        1.124594e+08     3.741492e+03  ...     0.000000     0.000000
# 50%        4.066180e+08     6.090908e+04  ...    12.430000     3.870000
# 75%        5.072356e+08     4.321621e+05  ...   396.107500    67.199500
# max        7.584308e+08     2.139776e+07  ...  4808.380000   386.820000
#
#               DOGE          XRP         GOLD       SILVER        COPPER
# count  4654.000000  4654.000000  4654.000000  4654.000000   4654.000000  \
# mean      0.026408     0.229873  1474.337129    21.657901   7112.199345
# std       0.069391     0.334681   253.778406     6.479395   1491.343889
# min       0.000000     0.000000  1049.600000    11.772000      0.000000
# 25%       0.000000     0.000000  1260.025000    16.624500   5947.125000
# 50%       0.000000     0.008870  1371.850000    19.570000   6962.000000
# 75%       0.003335     0.350712  1721.025000    25.340750   8151.437500
# max       0.686880     2.780000  2069.400000    48.599000  10674.000000
#
#             S&P500           DJI         JP225
# count  4654.000000   4654.000000   4654.000000
# mean   2492.349280  21487.496401  18751.425404
# std     989.044608   7511.506584   6322.971966
# min    1047.220000   9985.810000   8160.010000
# 25%    1697.435000  15464.300000  14313.030000
# 50%    2204.720000  19161.280000  19435.830000
# 75%    3046.155000  26828.202500  22902.512500
# max    4796.560000  36799.650000  30670.100000
#
# [8 rows x 23 columns]

# %%
sns.heatmap(df.corr(), cmap="RdBu")
# Out:
# <Axes: >

# %% [markdown]
# # Slpit Data (Testing, Training Data Sets)

# %%
from datetime import datetime

for index in total.index:
    total.loc[index, "Date"] = datetime.strptime(str(total.loc[index, "Date"])[:10], '%Y-%m-%d').date()

Start_day = date(2018, 10, 1)
Test_day = date(2022,11,1)
#chon ra 20-25% data trong giai doan 1
End_day = date(2023,4,16)
# train, test
total = total[(total["Date"] >= Start_day) & (total["Date"] <= End_day)].reset_index(drop = True)
train_dataset = total[total["Date"] < Test_day].reset_index(drop = True)
test_dataset = total[total["Date"] >= Test_day].reset_index(drop = True)

# %%
X_train = train_dataset.drop(["Date"], axis=1)[:-1]
y_train = train_dataset["BTC_close"][1:].reset_index(drop=True)

X_test = test_dataset.drop(["Date"], axis=1)[:-1]
y_test = test_dataset["BTC_close"][1:].reset_index(drop=True)

# %%
print("Kích thước X_train:", X_train.shape)
print("Kích thước y_train:", y_train.shape)
print("Kích thước X_test:", X_test.shape)
print("Kích thước y_test:", y_test.shape)
# Out:
# Kích thước X_train: (1491, 23)
# Kích thước y_train: (1491,)
# Kích thước X_test: (166, 23)
# Kích thước y_test: (166,)

# %% [markdown]
# # Load Model

# %%
#import sklearn modules
import time
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %% [markdown]
# ## Default

# %%
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np
y_train_pred = randmf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Square Error (RMSE):", rmse)

#MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print(" Mean Absolute Percentage Error (MAPE):", mape)
print()
AUC = AUC(y_test, y_pred)
#AUC
print("AUC test:", AUC)

# %% [markdown]
# ## Tuning

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# Define the range of values for n_estimators
n_estimators = [int(x) for x in np.linspace(start=100, stop=1000, num=10)]
max_depth = [int(x) for x in np.linspace(2, 10, num = 5)]
max_features = ['sqrt', 'log2', None]
bootstrap = [True, False] # method used to sample data points

param_grid = {'n_estimators': n_estimators,

'max_features': max_features,

'max_depth': max_depth,

'bootstrap': bootstrap}

print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000], 'max_features': ['sqrt', 'log2', None], 'max_depth': [2, 4, 6, 8, 10], 'bootstrap': [True, False]}

# %% [markdown]
# ### Randomized Search

# %%
from sklearn.model_selection import GridSearchCV
rf_random = RandomSearchCV(estimator = rf, param_grid = param_grid, cv = 10, verbose=2, n_jobs = -1)

scoring = make_scorer(mean_squared_error, greater_is_better=False)

# Create the RandomizedSearchCV object with early stopping
rf_random = RandomSearchCV(estimator=rf, param_grid = param_grid, scoring=scoring,
                                   cv=10, refit=True, verbose=2,
                                   n_jobs = -1, random_state=42)

# %%
rf_random.fit(X_train, y_train)

# %%
print ('Best Parameters: ', rf_random.best_params_)
print("Best RMSE Score: ", rf_random.best_score_)

# %% [markdown]
# ### Grid Search

# %%
from sklearn.model_selection import GridSearchCV

# Define the scoring function (negative mean squared error)
scoring = make_scorer(mean_squared_error, greater_is_better=False)

# Create the GridSearchCV object with early stopping
rf_Grid = GridSearchCV(estimator=rf, param_grid=param_grid, scoring=scoring,
                           cv=10, refit=True, verbose=2,
                           n_jobs=-1, iid=False)

# %%
rf_Grid.fit(X_train, y_train)
# Out:
# Fitting 100 folds for each of 300 candidates, totalling 30000 fits
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   9.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=   9.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  11.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.7s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  11.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.8s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=400; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=200; total time=   2.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=300; total time=   4.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=400; total time=   6.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=500; total time=   7.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   9.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=600; total time=   8.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  10.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=700; total time=  11.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  11.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=800; total time=  12.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  12.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=900; total time=  13.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.0s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.4s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.2s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  14.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, n_estimators=1000; total time=  15.2s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.6s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=100; total time=   1.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.1s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=200; total time=   3.0s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=log2, n_estimators=300; total time=   4.5s
# ...
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  19.6s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, n_estimators=1000; total time=  19.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   2.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=100; total time=   1.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   4.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=200; total time=   3.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=300; total time=   5.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=400; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=   9.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  10.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  11.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  12.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  13.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=500; total time=  13.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  13.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  13.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  16.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  14.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  13.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  12.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=600; total time=  11.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  12.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=700; total time=  13.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  15.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  15.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  16.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  17.2s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  16.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  15.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  15.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  14.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  14.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  14.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  14.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  15.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=800; total time=  15.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  17.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  17.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.7s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=900; total time=  16.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.5s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.6s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  17.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.8s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.0s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  18.3s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  17.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  17.9s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  19.4s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  19.1s
# [CV] END bootstrap=False, max_depth=10, max_features=log2, n_estimators=1000; total time=  19.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   8.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=100; total time=   7.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.6s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.8s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  16.5s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  16.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.6s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.6s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.5s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.7s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.5s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  15.5s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  16.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=200; total time=  16.3s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  24.1s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  23.6s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  23.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  23.0s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  22.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  22.9s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  23.4s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  23.2s
# [CV] END bootstrap=False, max_depth=10, max_features=None, n_estimators=300; total time=  23.6s
# GridSearchCV(cv=100, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [2, 4, 6, 8, 10],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [100, 200, 300, 400, 500, 600, 700,
#                                           800, 900, 1000]},
#              verbose=2)

# %%
print ('Best Parameters: ', rf_Grid.best_params_)
print("Best RMSE Score: ", rf_Grid.best_score_)
# Out:
# Best Parameters:  {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 800}

# %% [markdown]
# ## Using the best parameters

# %% [markdown]
# ### Randomized Search

# %%
start_time = time.time()

randmf = RandomForestRegressor(**rf_random.best_params_) 
randmf.fit(X_train, y_train) 

end_time = time.time()
all_rand_run_time = end_time - start_time

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_rand = gridmf.predict(X_test)

plt.figure(figsize=(5, 7))

sns.kdeplot(y_test, color="r", label="Actual Value")
sns.kdeplot(y_pred_rand, color="b", label="Fitted Values")

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
plt.close()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np
y_train_rand_pred = randmf.predict(X_train)

print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_rand_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_rand_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse_all_rand = np.sqrt(mean_squared_error(y_test, y_pred_rand))
print("Root Mean Square Error (RMSE):", rmse_all_rand)

#MAPE
mape_all_rand = mean_absolute_percentage_error(y_test, y_pred_rand)
print(" Mean Absolute Percentage Error (MAPE):", mape_all_rand)
print()
AUC_all_rand = AUC(y_test, y_pred_rand)
#AUC
print("AUC test:", AUC_all_rand)

# %% [markdown]
# ### Grid Search

# %%
start_time = time.time()

gridmf = RandomForestRegressor(**rf_Grid.best_params_) 
gridmf.fit(X_train, y_train) 

end_time = time.time()
all_grid_run_time = end_time - start_time

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_grid = gridmf.predict(X_test)

plt.figure(figsize=(5, 7))

sns.kdeplot(y_test, color="r", label="Actual Value")
sns.kdeplot(y_pred_grid, color="b", label="Fitted Values")

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
plt.close()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np

y_train_grid_pred = gridmf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_grid_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_grid_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse_all_grid = np.sqrt(mean_squared_error(y_test, y_pred_grid))
print("Root Mean Square Error (RMSE):", rmse_all_grid)

#MAPE
mape_all_grid = mean_absolute_percentage_error(y_test, y_pred_grid)
print(" Mean Absolute Percentage Error (MAPE):", mape_all_grid)
print()
AUC_all_grid = AUC(y_test, y_pred_grid)
#AUC
print("AUC test:", AUC_all_grid)
# Out:
# Test accuracy for train set
# Root Mean Square Error (RMSE): 9.058868769114845
# Mean Absolute Percentage Error (MAPE): 0.0005278343170048201
#
# Test accuracy for test set
# Root Mean Square Error (RMSE): 305.38999185558225
#  Mean Absolute Percentage Error (MAPE): 0.00893355364406968
#
# AUC test: 0.7818181818181819

# %% [markdown]
# ## Feature Reduction

# %% [markdown]
# ### Randomized Search

# %%
features_rand = X_train.columns
# Get numerical feature importances
importances_rand = list(randmf.feature_importances_)
# List of tuples with variable and importance
feature_importances_rand = [(feature, round(importance, 4)) for feature, importance in zip(features_rand, importances_rand)]
# Sort the feature importances by most important first
feature_importances_rand = sorted(feature_importances_rand, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_rand]
# Out:
# Variable: BTC_open             Importance: 0.9529
# Variable: BTC_low              Importance: 0.047
# Variable: BTC_close            Importance: 0.0
# Variable: BTC_high             Importance: 0.0
# Variable: BTC_volume           Importance: 0.0
# Variable: Active_Addr_Cnt      Importance: 0.0
# Variable: Difficulty           Importance: 0.0
# Variable: Mean_Block_Size(in_bytes) Importance: 0.0
# Variable: Sum_Block_Weight     Importance: 0.0
# Variable: Total_Fees(USD)      Importance: 0.0
# Variable: Mean_Hashrate        Importance: 0.0
# Variable: Xfer_Cnt             Importance: 0.0
# Variable: Mean_Tx_size(native_units) Importance: 0.0
# Variable: ETH                  Importance: 0.0
# Variable: LTC                  Importance: 0.0
# Variable: DOGE                 Importance: 0.0
# Variable: XRP                  Importance: 0.0
# Variable: GOLD                 Importance: 0.0
# Variable: SILVER               Importance: 0.0
# Variable: COPPER               Importance: 0.0
# Variable: S&P500               Importance: 0.0
# Variable: DJI                  Importance: 0.0
# Variable: JP225                Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# list of x locations for plotting
x_values = list(range(len(importances_rand)))
# Make a bar chart
plt.bar(x_values, importances_rand, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)
# Tick labels for x axis
plt.xticks(x_values, features_rand, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# List of features sorted from most to least important
sorted_importances_rand = [importance[1] for importance in feature_importances_rand]
sorted_features_rand = [importance[0] for importance in feature_importances_rand]
# Cumulative importances
cumulative_importances_rand = np.cumsum(sorted_importances_rand)
# Make a line graph
plt.plot(x_values, cumulative_importances_rand, 'g-')
# Draw line at 95% of importance retained
plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances_rand), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(x_values, sorted_features_rand, rotation = 'vertical')
# Axis labels and title
plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');

# %%
# Find number of features for cumulative importance of 95%
# Add 1 because Python is zero-indexed
num_rand = np.where(cumulative_importances_rand > 0.95)[0][0] + 1
print('Number of features for 95% importance:', num_rand)
# Out:
# Number of features for 95% importance: 1

# %%
# Extract the names of the most important features
important_feature_names_rand = [feature[0] for feature in feature_importances_rand[0:num]]
print(important_feature_names_rand)
# Out:
# ['BTC_open']

# %%
train_data_rand = X_train[important_feature_names_rand]
test_data_rand = X_test[important_feature_names_rand]
# Sanity check on operations
print('Important train features shape:', train_data_rand.shape)
print('Important test features shape:', test_data_rand.shape)
# Out:
# Important train features shape: (1491, 1)
# Important test features shape: (166, 1)

# %% [markdown]
# ### Grid Search

# %%
features_grid = X_train.columns
# Get numerical feature importances
importances_grid = list(gridmf.feature_importances_)
# List of tuples with variable and importance
feature_importances_grid = [(feature, round(importance, 4)) for feature, importance in zip(features_grid, importances_grid)]
# Sort the feature importances by most important first
feature_importances_grid = sorted(feature_importances_grid, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances_grid]

# %%
# list of x locations for plotting
x_values = list(range(len(importances_rand)))
# Make a bar chart
plt.bar(x_values, importances_rand, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)
# Tick labels for x axis
plt.xticks(x_values, features_rand, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# List of features sorted from most to least important
sorted_importances_grid = [importance[1] for importance in feature_importances_grid]
sorted_features_grid = [importance[0] for importance in feature_importances_grid]
# Cumulative importances
cumulative_importances_grid = np.cumsum(sorted_importances_grid)
# Make a line graph
plt.plot(x_values, cumulative_importances_grid, 'g-')
# Draw line at 95% of importance retained
plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances_grid), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(x_values, sorted_features_grid, rotation = 'vertical')
# Axis labels and title
plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');

# %%
# Find number of features for cumulative importance of 95%
# Add 1 because Python is zero-indexed
num_rand = np.where(cumulative_importances_rand > 0.95)[0][0] + 1
print('Number of features for 95% importance:', num_rand)

# %%
# Extract the names of the most important features
important_feature_names_grid = [feature[0] for feature in feature_importances_grid[0:num]]
print(important_feature_names_grid)

# %%
train_data_grid = X_train[important_feature_names_grid]
test_data_grid = X_test[important_feature_names_grid]
# Sanity check on operations
print('Important train features shape:', train_data_grid.shape)
print('Important test features shape:', test_data_grid.shape)

# %% [markdown]
# #### Training and Evaluating on Important Features

# %% [markdown]
# ### Randomized Search

# %%
start_time = time.time()

# Train the expanded model on only the important features
randmf.fit(train_data_rand, y_train);

# Make predictions on test data
predictions_rand = randmf.predict(test_data_rand)

end_time = time.time()
reduce_rand_run_time = end_time - start_time

#RMSE
from sklearn.metrics import mean_squared_error
rmse_reduce_rand = np.sqrt(mean_squared_error(y_test, predictions_rand))
print("RMSE:", rmse_reduce_rand)
print()

#MAPE
mape_reduce_rand = np.average(np.abs((y_test - predictions_rand) / y_test))
print("MAPE:", mape_reduce_rand)
print()

AUC_reduce_rand = AUC(np.array(y_test), predictions_rand)
print("AUC test:", AUC_reduce_rand )

# %% [markdown]
# ### Grid Search

# %%
start_time = time.time()

# Train the expanded model on only the important features
gridmf.fit(train_data_grid, y_train);

# Make predictions on test data
predictions_grid = gridmf.predict(test_data_grid)

end_time = time.time()
reduce_grid_run_time = end_time - start_time

#RMSE
from sklearn.metrics import mean_squared_error
rmse_reduce_grid = np.sqrt(mean_squared_error(y_test, predictions_grid))
print("RMSE:", rmse_reduce_grid)
print()

#MAPE
mape_reduce_grid = np.average(np.abs((y_test - predictions_grid) / y_test))
print("MAPE:", mape_reduce_grid)
print()

AUC_reduce_grid = AUC(np.array(y_test), predictions_grid)
print("AUC test:", AUC_reduce_grid )
# Out:
# RMSE: 128.87536280535176
#
# MAPE: 0.003911759621384725
#
# AUC test: 0.703030303030303

# %% [markdown]
# #### Normalization with original data

# %% [markdown]
# ### Randomized Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_all_rand = MinMaxScaler()
X_train_normalized_all_rand = scaler_all_rand.fit_transform(X_train)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_all_rand = scaler_all_rand.transform(X_test)

# %%
rf_regressor_all_rand = RandomForestRegressor(**rf_random.best_params_)

start_time = time.time()

rf_regressor_all_rand.fit(X_train_normalized_all_rand, y_train)

y_pred_norma_all_rand = rf_regressor_all_rand.predict(X_test_normalized_all_rand)

end_time = time.time()
normal_all_rand_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_all_rand = np.sqrt(mean_squared_error(y_test, y_pred_norma_all_rand))
print("RMSE:", rmse_normal_all_rand)
print()

#MAPE
mape_normal_all_rand = np.average(np.abs((y_test - y_pred_norma_all_rand) / y_test))
print("MAPE:", mape_normal_all_rand)
print()

AUC_normal_all_rand = AUC(np.array(y_test), y_pred_norma_all_rand)
print("AUC test:", AUC_normal_all_rand )

# %% [markdown]
# ### Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_all_grid = MinMaxScaler()
X_train_normalized_all_grid = scaler_all_grid.fit_transform(X_train)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_all_grid = scaler_all_grid.transform(X_test)

# %%
rf_regressor_all_grid = RandomForestRegressor(**rf_Grid.best_params_)

start_time = time.time()

rf_regressor_all_grid.fit(X_train_normalized_all_grid, y_train)

y_pred_norma_all_grid = rf_regressor_all_grid.predict(X_test_normalized_all_grid)

end_time = time.time()
normal_all_grid_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_all_grid = np.sqrt(mean_squared_error(y_test, y_pred_norma_all_grid))
print("RMSE:", rmse_normal_all_rand)
print()

#MAPE
mape_normal_all_grid = np.average(np.abs((y_test - y_pred_norma_all_grid) / y_test))
print("MAPE:", mape_normal_all_grid)
print()

AUC_normal_all_grid = AUC(np.array(y_test), y_pred_norma_all_grid)
print("AUC test:", AUC_normal_all_grid )
# Out:
# RMSE: 308.7578756311196
#
# MAPE: 0.008963109548169174
#
# AUC test: 0.7818181818181819

# %% [markdown]
# #### Normalization with Importance Features

# %% [markdown]
# ### Radomized Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_reduce_rand = MinMaxScaler()
X_train_normalized_reduce_rand = scaler_reduce_rand.fit_transform(train_data_rand)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_reduce_rand = scaler_reduce_rand.transform(test_data_rand)

# %%
rf_regressor_reduce_rand = RandomForestRegressor(**rf_random.best_params_)

start_time = time.time()
rf_regressor_reduce_rand.fit(X_train_normalized_reduce_rand, y_train)

y_pred_norma_reduce_rand = rf_regressor_reduce_rand.predict(X_test_normalized_reduce_rand)

end_time = time.time()
normal_reduce_rand_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_reduce_rand = np.sqrt(mean_squared_error(y_test, y_pred_norma_reduce_rand))
print("RMSE:", rmse_normal_reduce_rand)
print()

#MAPE
mape_normal_reduce_rand = np.average(np.abs((y_test - y_pred_norma_reduce_rand) / y_test))
print("MAPE:", mape_normal_reduce_rand)
print()

AUC_normal_reduce_rand = AUC(np.array(y_test), y_pred_norma_reduce_rand)
print("AUC test:", AUC_normal_reduce_rand)

# %% [markdown]
# ### Grid Search

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the features using MinMaxScaler for the training dataset
scaler_grid = MinMaxScaler()
X_train_normalized_reduce_grid = scaler.fit_transform(train_data_grid)

# Normalize the features using the same scaler for the testing dataset
X_test_normalized_reduce_grid = scaler.transform(test_data_grid)

# %%
rf_regressor_reduce_grid = RandomForestRegressor(**rf_Grid.best_params_)

start_time = time.time()
rf_regressor_reduce_grid.fit(X_train_normalized_reduce_grid, y_train)

y_pred_norma_reduce_grid = rf_regressor_reduce_grid.predict(X_test_normalized_reduce_grid)

end_time = time.time()
normal_reduce_grid_run_time = end_time - start_time

from sklearn.metrics import mean_squared_error

#RMSE
from sklearn.metrics import mean_squared_error
rmse_normal_reduce_grid = np.sqrt(mean_squared_error(y_test, y_pred_norma_reduce_grid))
print("RMSE:", rmse_normal_reduce_grid)
print()

#MAPE
mape_normal_reduce_grid = np.average(np.abs((y_test - y_pred_norma_reduce_grid) / y_test))
print("MAPE:", mape_normal_reduce_rand)
print()

AUC_normal_reduce_grid = AUC(np.array(y_test), y_pred_norma_reduce_grid)
print("AUC test:", AUC_normal_reduce_grid)
# Out:
# RMSE: 128.87536280535176
#
# MAPE: 0.003911759621384725
#
# AUC test: 0.703030303030303

# %% [markdown]
# ## Summary statistical table

# %% [markdown]
# ### Randomized Search

# %%
def print_results_rand(AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time, 
                       AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time, 
                  AUC_normal_all_rand, rmse_normal_all_rand, mape_normal_all_rand, normal_all_rand_run_time,
                 AUC_normal_reduce_rand, rmse_normal_reduce_rand, mape_normal_reduce_rand, normal_reduce_rand_run_time):
    headers = ['Type', 'Number of Features','Accuracy', 'RMSE', 'MAPE', 'Run Time (s)']
    all_results = [['All', len(importances), AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time],
                   ['Reduce', len(important_feature_names), AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time],
                   ['Normalization - All', len(importances), AUC_normal_all_rand, rmse_normal_all_rand, mape_normal_all_rand, normal_all_rand_run_time],
                  ['Normalization - Reduce', len(important_feature_names), AUC_normal_reduce_rand, rmse_normal_reduce_rand, mape_normal_reduce_rand, normal_reduce_rand_run_time]]

    # Calculate the maximum width for each column
    col_widths = [max(len(str(row[i])) for row in all_results + [headers]) for i in range(len(headers))]

    # Print table headers
    header_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    print(header_format.format(*headers))

    # Print separator row
    separator = '-' * (sum(col_widths) + 3 * (len(col_widths) - 1))
    print(separator)

    # Print table rows
    row_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    for result in all_results:
        index, num_features, AUC, rmse, mape, run_time = result
        print(row_format.format(index, num_features, AUC, rmse, mape, run_time))
        
print_results_rand(AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time, 
                       AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time, 
                  AUC_normal_all_rand, rmse_normal_all_rand, mape_normal_all_rand, normal_all_rand_run_time,
                 AUC_normal_reduce_rand, rmse_normal_reduce_rand, mape_normal_reduce_rand, normal_reduce_rand_run_time)

# %% [markdown]
# ### Grid Search

# %%
def print_results_rand(AUC_all_grid, rmse_all_grid, mape_all_grid, all_grid_run_time, 
                       AUC_reduce_grid, rmse_reduce_grid, mape_reduce_grid, reduce_grid_run_time, 
                  AUC_normal_all_grid, rmse_normal_all_grid, mape_normal_all_grid, normal_all_grid_run_time,
                 AUC_normal_reduce_grid, rmse_normal_reduce_grid, mape_normal_reduce_grid, normal_reduce_grid_run_time):
    headers = ['Type', 'Number of Features','Accuracy', 'RMSE', 'MAPE', 'Run Time (s)']
    all_results = [['All', len(importances), AUC_all_grid, rmse_all_grid, mape_all_grid, all_grid_run_time],
                   ['Reduce', len(important_feature_names), AUC_reduce_grid, rmse_reduce_grid, mape_reduce_grid, reduce_grid_run_time],
                   ['Normalization - All', len(importances), AUC_normal_all_grid, rmse_normal_all_grid, mape_normal_all_grid, normal_all_grid_run_time],
                  ['Normalization - Reduce', len(important_feature_names), AUC_normal_reduce_grid, rmse_normal_reduce_grid, mape_normal_reduce_grid, normal_reduce_grid_run_time]]

    # Calculate the maximum width for each column
    col_widths = [max(len(str(row[i])) for row in all_results + [headers]) for i in range(len(headers))]

    # Print table headers
    header_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    print(header_format.format(*headers))

    # Print separator row
    separator = '-' * (sum(col_widths) + 3 * (len(col_widths) - 1))
    print(separator)

    # Print table rows
    row_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    for result in all_results:
        index, num_features, AUC, rmse, mape, run_time = result
        print(row_format.format(index, num_features, AUC, rmse, mape, run_time))
        
print_results_rand(AUC_all_grid, rmse_all_grid, mape_all_grid, all_grid_run_time, 
                       AUC_reduce_grid, rmse_reduce_grid, mape_reduce_grid, reduce_grid_run_time, 
                  AUC_normal_all_grid, rmse_normal_all_grid, mape_normal_all_grid, normal_all_grid_run_time,
                 AUC_normal_reduce_grid, rmse_normal_reduce_grid, mape_normal_reduce_grid, normal_reduce_grid_run_time)
# Out:
# Type                    Number of Features  Accuracy            RMSE                MAPE                  Run Time (s)
# --------------------------------------------------------------------------------------------------------------------------------
# All                     23                  0.7818181818181819  305.38999185558225  0.00893355364406968   38.60229563713074
# Reduce                  1                   0.703030303030303   128.87536280535176  0.003911759621384725  4.277912139892578
# Normalization - All     23                  0.7818181818181819  308.7578756311196   0.008963109548169174  39.96969223022461
# Normalization - Reduce  1                   0.703030303030303   128.87536280535176  0.003911759621384725  4.740701913833618

# %% [markdown]
# # Graph Predicted Values with Test Set

# %% [markdown]
# ### Randomized Search

# %%
#hien thi ket qua du doan
fig, ax = plt.subplots(1, 1, figsize=(14, 5))
ax.plot(y_test, color = 'red', label="Bitcoin Price")
ax.plot(y_pred_rand, color = 'green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))  # .3f
plt.title("Random Forest Regression for Period 2")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 5))

ax.plot(total['Date'], total['BTC_close'], color='red', label="Bitcoin Price")
ax.plot(total['Date'][-len(y_train):], y_train, color='blue', label="Training Data")
ax.plot(total['Date'][:len(y_test)], y_test, color='orange', label="Test Data")
ax.plot(total['Date'][:len(y_pred)], y_pred_rand, color='green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # Định dạng đường trục y
plt.legend()
plt.show()

# %% [markdown]
# ### Grid Search

# %%
#hien thi ket qua du doan
fig, ax = plt.subplots(1, 1, figsize=(14, 5))
ax.plot(y_test, color = 'red', label="Bitcoin Price")
ax.plot(y_pred_grid, color = 'green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))  # .3f
plt.title("Random Forest Regression for Period 2")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 5))

ax.plot(total['Date'], total['BTC_close'], color='red', label="Bitcoin Price")
ax.plot(total['Date'][-len(y_train):], y_train, color='blue', label="Training Data")
ax.plot(total['Date'][:len(y_test)], y_test, color='orange', label="Test Data")
ax.plot(total['Date'][:len(y_pred)], y_pred_grid, color='green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # Định dạng đường trục y
plt.legend()
plt.show()

# %% [markdown]
# ## Comparing randomized search and grid search for hyperparameter estimation

# %%
import numpy as np

from time import time
import scipy.stats as stats
from sklearn.utils.fixes import loguniform

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.datasets import load_digits
from sklearn.linear_model import SGDClassifier


# Utility function to report best scores
def report(results, n_top=10):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results["rank_test_score"] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print(
                "Mean validation score: {0:.3f} (std: {1:.3f})".format(
                    results["mean_test_score"][candidate],
                    results["std_test_score"][candidate],
                )
            )
            print("Parameters: {0}".format(results["params"][candidate]))
            print("")

# %% [markdown]
# #### Randomized Search

# %%
print(
    "RandomizedSearchCV took %.2f seconds for %d candidates parameter settings."
    % ((time() - start), n_iter_search)
)
report(random_search.cv_results_)

# %% [markdown]
# #### Grid Search

# %%
print((len(rf_Grid.cv_results_["params"])))
report(rf_Grid.cv_results_)
# Out:
# 300
# Model with rank: 1
# Mean validation score: 0.965 (std: 0.082)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 800}
#
# Model with rank: 2
# Mean validation score: 0.965 (std: 0.083)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 300}
#
# Model with rank: 3
# Mean validation score: 0.965 (std: 0.083)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 900}
#
# Model with rank: 4
# Mean validation score: 0.964 (std: 0.083)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 700}
#
# Model with rank: 5
# Mean validation score: 0.964 (std: 0.083)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 1000}
#
# Model with rank: 6
# Mean validation score: 0.964 (std: 0.085)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 400}
#
# Model with rank: 7
# Mean validation score: 0.964 (std: 0.084)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 600}
#
# Model with rank: 8
# Mean validation score: 0.964 (std: 0.084)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 200}
#
# Model with rank: 9
# Mean validation score: 0.964 (std: 0.084)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 500}
#
# Model with rank: 10
# Mean validation score: 0.962 (std: 0.088)
# Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': None, 'n_estimators': 100}

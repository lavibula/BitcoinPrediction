# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, date
import seaborn as sns

# %% [markdown]
# # Load Data
# * Handle missing values, duplicated values, outlier

# %%
total = pd.read_csv("https://raw.githubusercontent.com/lavibula/ML20222.PredictionBitcoin/main/data/saved_data.csv")
total['Date'] = pd.to_datetime(total['Date'])

df = total.set_index('Date')
df.head()
# Out:
#             BTC_close  BTC_open  BTC_high  BTC_low  BTC_volume
# Date
# 2023-04-16    30310.3   30299.2   30545.3  30134.6       34.48  \
# 2023-04-15    30299.6   30472.6   30586.5  30208.8       31.71
# 2023-04-14    30472.5   30387.4   30964.9  30026.0       98.38
# 2023-04-13    30387.4   29892.4   30524.1  29864.5       65.87
# 2023-04-12    29886.4   30209.8   30473.0  29679.5       78.69
#
#             Active_Addr_Cnt    Difficulty  Mean_Block_Size(in_bytes)
# Date
# 2023-04-16         840992.0  4.788780e+13                1866594.290  \
# 2023-04-15        1045660.0  4.788780e+13                1839875.354
# 2023-04-14        1016042.0  4.788780e+13                1759535.436
# 2023-04-13        1009669.0  4.788780e+13                1812112.549
# 2023-04-12        1056542.0  4.788780e+13                1933495.919
#
#             Sum_Block_Weight  Total_Fees(USD)  ...      ETH     LTC      DOGE
# Date                                           ...
# 2023-04-16       495223185.0    484205.915377  ...  2119.29  100.03  0.090465  \
# 2023-04-15       631025193.0    630623.285367  ...  2090.59   96.66  0.088890
# 2023-04-14       559166432.0    858535.297189  ...  2099.98   96.34  0.088707
# 2023-04-13       567094231.0    767012.808110  ...  2012.11   94.19  0.087344
# 2023-04-12       635037442.0    757368.783682  ...  1916.58   92.02  0.083398
#
#                 XRP    GOLD  SILVER  COPPER   S&P500       DJI     JP225
# Date
# 2023-04-16  0.52089  2015.6  25.438  9023.5  4137.64  33885.31  28493.47
# 2023-04-15  0.51930  2002.2  25.460  9023.5  4137.64  33885.31  28493.47
# 2023-04-14  0.52269  2002.2  25.460  9023.5  4137.64  33885.31  28493.47
# 2023-04-13  0.51244  2041.3  25.925  9058.5  4146.22  34030.34  28156.97
# 2023-04-12  0.50473  2010.9  25.458  8916.5  4091.95  33647.22  28082.70
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (4654, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4654 entries, 2023-04-16 to 2010-07-20
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   BTC_close                   4654 non-null   float64
#  1   BTC_open                    4654 non-null   float64
#  2   BTC_high                    4654 non-null   float64
#  3   BTC_low                     4654 non-null   float64
#  4   BTC_volume                  4654 non-null   float64
#  5   Active_Addr_Cnt             4654 non-null   float64
#  6   Difficulty                  4654 non-null   float64
#  7   Mean_Block_Size(in_bytes)   4654 non-null   float64
#  8   Sum_Block_Weight            4654 non-null   float64
#  9   Total_Fees(USD)             4654 non-null   float64
#  10  Mean_Hashrate               4654 non-null   float64
#  11  Xfer_Cnt                    4654 non-null   float64
#  12  Mean_Tx_size(native_units)  4654 non-null   float64
#  13  ETH                         4654 non-null   float64
#  14  LTC                         4654 non-null   float64
#  15  DOGE                        4654 non-null   float64
#  16  XRP                         4654 non-null   float64
#  17  GOLD                        4654 non-null   float64
#  18  SILVER                      4654 non-null   float64
#  19  COPPER                      4654 non-null   float64
#  20  S&P500                      4654 non-null   float64
#  21  DJI                         4654 non-null   float64
#  22  JP225                       4654 non-null   float64
# dtypes: float64(23)
# memory usage: 872.6 KB

# %%
df.describe()
# Out:
#           BTC_close      BTC_open      BTC_high       BTC_low   BTC_volume
# count   4654.000000   4654.000000   4654.000000   4654.000000  4654.000000  \
# mean    8950.828126   8944.396197   9182.648904   8680.543532   144.272183
# std    14517.759120  14515.100053  14900.138248  14078.916437   199.685947
# min        0.100000      0.100000      0.100000      0.000000     0.170000
# 25%      140.475000    140.400000    145.800000    135.825000    25.407500
# 50%      916.050000    915.050000    934.150000    877.350000    63.605000
# 75%     9932.450000   9926.450000  10231.950000   9636.050000   158.375000
# max    67527.900000  67528.700000  68990.600000  66334.900000   999.530000
#
#        Active_Addr_Cnt    Difficulty  Mean_Block_Size(in_bytes)
# count     4.654000e+03  4.654000e+03               4.654000e+03  \
# mean      4.974545e+05  7.399910e+12               6.883463e+05
# std       3.731797e+05  1.103629e+13               4.990862e+05
# min       4.080000e+02  1.820000e+02               4.164167e+02
# 25%       8.702175e+04  1.322172e+08               1.656955e+05
# 50%       5.389900e+05  2.840750e+11               7.887917e+05
# 75%       8.174050e+05  1.389755e+13               1.087807e+06
# max       1.366494e+06  4.788780e+13               2.535436e+06
#
#        Sum_Block_Weight  Total_Fees(USD)  ...          ETH          LTC
# count      4.654000e+03     4.654000e+03  ...  4654.000000  4654.000000  \
# mean       3.329426e+08     5.498044e+05  ...   505.010290    45.052975
# std        2.151278e+08     1.528054e+06  ...   945.449318    63.364718
# min        2.841400e+05     0.000000e+00  ...     0.000000     0.000000
# 25%        1.124594e+08     3.741492e+03  ...     0.000000     0.000000
# 50%        4.066180e+08     6.090908e+04  ...    12.430000     3.870000
# 75%        5.072356e+08     4.321621e+05  ...   396.107500    67.199500
# max        7.584308e+08     2.139776e+07  ...  4808.380000   386.820000
#
#               DOGE          XRP         GOLD       SILVER        COPPER
# count  4654.000000  4654.000000  4654.000000  4654.000000   4654.000000  \
# mean      0.026408     0.229873  1474.337129    21.657901   7112.199345
# std       0.069391     0.334681   253.778406     6.479395   1491.343889
# min       0.000000     0.000000  1049.600000    11.772000      0.000000
# 25%       0.000000     0.000000  1260.025000    16.624500   5947.125000
# 50%       0.000000     0.008870  1371.850000    19.570000   6962.000000
# 75%       0.003335     0.350712  1721.025000    25.340750   8151.437500
# max       0.686880     2.780000  2069.400000    48.599000  10674.000000
#
#             S&P500           DJI         JP225
# count  4654.000000   4654.000000   4654.000000
# mean   2492.349280  21487.496401  18751.425404
# std     989.044608   7511.506584   6322.971966
# min    1047.220000   9985.810000   8160.010000
# 25%    1697.435000  15464.300000  14313.030000
# 50%    2204.720000  19161.280000  19435.830000
# 75%    3046.155000  26828.202500  22902.512500
# max    4796.560000  36799.650000  30670.100000
#
# [8 rows x 23 columns]

# %%
sns.heatmap(df.corr(), cmap="RdBu")
# Out:
# <Axes: >

# %% [markdown]
# # Slpit Data (Testing, Training Data Sets)

# %%
from datetime import datetime

for index in total.index:
    total.loc[index, "Date"] = datetime.strptime(str(total.loc[index, "Date"])[:10], '%Y-%m-%d').date()

Start_day = date(2018, 10, 1)

Test_day = date(2021,10,16)

End_day = date(2023,4,16)

# train, test
total = total[(total["Date"] >= Start_day) & (total["Date"] <= End_day)].reset_index(drop = True)
train_dataset = total[total["Date"] < Test_day].reset_index(drop = True)
test_dataset = total[total["Date"] >= Test_day].reset_index(drop = True)

# %%
X_train = train_dataset.drop(["Date"], axis=1)[:-1]
y_train = train_dataset["BTC_close"][1:].reset_index(drop=True)

X_test = test_dataset.drop(["Date"], axis=1)[:-1]
y_test = test_dataset["BTC_close"][1:].reset_index(drop=True)

# %%
test_ratio = len(test_dataset) / len(total)

print("Tỉ lệ test_data/total:", test_ratio)
# Out:
# Tỉ lệ test_data/total: 0.3303194695599759

# %%
print("Kích thước X_train:", X_train.shape)
print("Kích thước y_train:", y_train.shape)
print("Kích thước X_test:", X_test.shape)
print("Kích thước y_test:", y_test.shape)
# Out:
# Kích thước X_train: (1110, 23)
# Kích thước y_train: (1110,)
# Kích thước X_test: (547, 23)
# Kích thước y_test: (547,)

# %% [markdown]
# # Load Model

# %%
#import sklearn modules
import time
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 100)

# %% [markdown]
# ## Default

# %%
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

# %%
sns.displot(y_test - y_pred, kde=True)
plt.xlabel('y_test - y_pred')
plt.ylabel('count')
plt.show()

# %% [markdown]
# The distribution of my data tends to curve up on the right side, which means there are some values that are higher than predicted. This can happen when the data has outliers or when the distribution of the data does not follow a normal distribution.

# %%
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel('y_test')
plt.ylabel('Predicted')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np
y_train_pred = rf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Square Error (RMSE):", rmse)

#MAPE
mape = mean_absolute_percentage_error(y_test, y_pred)
print(" Mean Absolute Percentage Error (MAPE):", mape)
print()
AUC = AUC(y_test, y_pred)
#AUC
print("AUC test:", AUC)
# Out:
# Test accuracy for train set
# Root Mean Square Error (RMSE): 58.615934273618926
# Mean Absolute Percentage Error (MAPE): 0.001201137971022384
#
# Test accuracy for test set
# Root Mean Square Error (RMSE): 2252.962179272978
#  Mean Absolute Percentage Error (MAPE): 0.07717167612516582
#
# AUC test: 0.7893772893772893

# %% [markdown]
# ## Tuning

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np

# Define the range of values for n_estimators

n_estimators = [int(x) for x in np.linspace(start=100, stop=500, num=5)]
max_depth = [int(x) for x in np.linspace(2, 10, num = 5)]
criterion = ['squared_error']
max_features = ['log2', 'sqrt', None]
min_samples_split = [2]
min_samples_leaf = [1]
bootstrap = [True, False] # method used to sample data points

param_grid = {'n_estimators': n_estimators,

'max_features': max_features,

'criterion': criterion,
            
''

'max_depth': max_depth,

'min_samples_split': min_samples_split,
              
'min_samples_leaf': min_samples_leaf,

'bootstrap': bootstrap}

print(param_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500], 'max_features': ['log2', 'sqrt', None], 'criterion': ['squared_error'], 'max_depth': [2, 4, 6, 8, 10], 'min_samples_split': [2], 'min_samples_leaf': [1], 'bootstrap': [True, False]}

# %% [markdown]
# ### Randomized Search

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer

scoring = make_scorer(mean_squared_error, greater_is_better=False)

# Create the RandomizedSearchCV object with early stopping
rf_random = RandomizedSearchCV(estimator=rf, param_distributions = param_grid, scoring=scoring,
                                   cv=5, refit=True, verbose=2,
                                   n_jobs = -1, random_state=42)

# %%
rf_random.fit(X_train, y_train)

print ('Best Parameters: ', rf_random.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Parameters:  {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': 6, 'criterion': 'squared_error', 'bootstrap': False}

# %% [markdown]
# ## Using the best parameters

# %% [markdown]
# ### Randomized Search

# %%
import time

start_time = time.time()

randmf = RandomForestRegressor(**rf_random.best_params_) 
randmf.fit(X_train, y_train) 

end_time = time.time()
all_rand_run_time = end_time - start_time

# %%
import seaborn as sns
import matplotlib.pyplot as plt

y_pred_rand = randmf.predict(X_test)

plt.figure(figsize=(5, 7))

sns.kdeplot(y_test, color="r", label="Actual Value")
sns.kdeplot(y_pred_rand, color="b", label="Fitted Values")

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price')
plt.ylabel('Density')
plt.legend()
plt.show()
plt.close()

# %%
sns.displot(y_test - y_pred_rand, kde=True)
plt.xlabel('y_test - y_pred_rand')
plt.ylabel('count')
plt.show()

# %%
sns.scatterplot(x=y_test, y=y_pred_rand)
plt.xlabel('y_test')
plt.ylabel('Predicted')
plt.show()

# %% [markdown]
# Mostly linearly correlated.

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_percentage_error
import numpy as np
y_train_rand_pred = randmf.predict(X_train)

y_test = np.array(y_test)

def AUC(y_test, y_pred):
    count = 0
    for i in range(1,len(y_test)):
        if (y_test[i] - y_test[i-1]) * (y_pred[i] - y_pred[i-1]) > 0:
            count += 1
    return count/(len(y_test)-1)
print("Test accuracy for train set")
#RMSE
print("Root Mean Square Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_rand_pred)))

#MAPE
print("Mean Absolute Percentage Error (MAPE):", mean_absolute_percentage_error(y_train,y_train_rand_pred))
print()

print("Test accuracy for test set")
#RMSE
rmse_all_rand = np.sqrt(mean_squared_error(y_test, y_pred_rand))
print("Root Mean Square Error (RMSE):", rmse_all_rand)

#MAPE
mape_all_rand = mean_absolute_percentage_error(y_test, y_pred_rand)
print(" Mean Absolute Percentage Error (MAPE):", mape_all_rand)
print()
AUC_all_rand = AUC(y_test, y_pred_rand)
#AUC
print("AUC test:", AUC_all_rand)
# Out:
# Test accuracy for train set
# Root Mean Square Error (RMSE): 206.30090965852807
# Mean Absolute Percentage Error (MAPE): 0.014090619783924787
#
# Test accuracy for test set
# Root Mean Square Error (RMSE): 1046.6956627869145
#  Mean Absolute Percentage Error (MAPE): 0.02748503356280206
#
# AUC test: 0.4816849816849817

# %% [markdown]
# ## Feature Reduction

# %% [markdown]
# ### Randomized Search

# %%
features_rand = X_train.columns
# Get numerical feature importances
importances_rand = list(randmf.feature_importances_)
# List of tuples with variable and importance
feature_importances_rand = [(feature, round(importance, 4)) for feature, importance in zip(features_rand, importances_rand)]
# Sort the feature importances by most important first
feature_importances_rand = sorted(feature_importances_rand, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
for pair in feature_importances_rand:
    print('Variable: {:20} Importance: {}'.format(*pair))
# Out:
# Variable: BTC_close            Importance: 0.8844
# Variable: BTC_open             Importance: 0.115
# Variable: BTC_high             Importance: 0.0002
# Variable: BTC_low              Importance: 0.0002
# Variable: LTC                  Importance: 0.0001
# Variable: SILVER               Importance: 0.0001
# Variable: BTC_volume           Importance: 0.0
# Variable: Active_Addr_Cnt      Importance: 0.0
# Variable: Difficulty           Importance: 0.0
# Variable: Mean_Block_Size(in_bytes) Importance: 0.0
# Variable: Sum_Block_Weight     Importance: 0.0
# Variable: Total_Fees(USD)      Importance: 0.0
# Variable: Mean_Hashrate        Importance: 0.0
# Variable: Xfer_Cnt             Importance: 0.0
# Variable: Mean_Tx_size(native_units) Importance: 0.0
# Variable: ETH                  Importance: 0.0
# Variable: DOGE                 Importance: 0.0
# Variable: XRP                  Importance: 0.0
# Variable: GOLD                 Importance: 0.0
# Variable: COPPER               Importance: 0.0
# Variable: S&P500               Importance: 0.0
# Variable: DJI                  Importance: 0.0
# Variable: JP225                Importance: 0.0

# %%
# list of x locations for plotting
x_values = list(range(len(importances_rand)))
# Make a bar chart
plt.bar(x_values, importances_rand, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)
# Tick labels for x axis
plt.xticks(x_values, features_rand, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# List of features sorted from most to least important
sorted_importances_rand = [importance[1] for importance in feature_importances_rand]
sorted_features_rand = [importance[0] for importance in feature_importances_rand]
# Cumulative importances
cumulative_importances_rand = np.cumsum(sorted_importances_rand)
# Make a line graph
plt.plot(x_values, cumulative_importances_rand, 'g-')
# Draw line at 90% of importance retained
plt.hlines(y = 0.9, xmin=0, xmax=len(sorted_importances_rand), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(x_values, sorted_features_rand, rotation = 'vertical')
# Axis labels and title
plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');

# %%
# Find number of features for cumulative importance of 90%
# Add 1 because Python is zero-indexed
num_rand = np.where(cumulative_importances_rand > 0.9)[0][0] + 1
print('Number of features for 90% importance:', num_rand)
# Out:
# Number of features for 90% importance: 2

# %%
# Extract the names of the most important features
important_feature_names_rand = [feature[0] for feature in feature_importances_rand[0:num_rand]]
print(important_feature_names_rand)
# Out:
# ['BTC_close', 'BTC_open']

# %%
train_data_rand = X_train[important_feature_names_rand]
test_data_rand = X_test[important_feature_names_rand]
# Sanity check on operations
print('Important train features shape:', train_data_rand.shape)
print('Important test features shape:', test_data_rand.shape)
# Out:
# Important train features shape: (1110, 2)
# Important test features shape: (547, 2)

# %% [markdown]
# #### Training and Evaluating on Important Features

# %% [markdown]
# ### Randomized Search

# %%
start_time = time.time()

# Train the expanded model on only the important features
randmf.fit(train_data_rand, y_train);

# Make predictions on test data
predictions_rand = randmf.predict(test_data_rand)

end_time = time.time()
reduce_rand_run_time = end_time - start_time

#RMSE
from sklearn.metrics import mean_squared_error
rmse_reduce_rand = np.sqrt(mean_squared_error(y_test, predictions_rand))
print("RMSE:", rmse_reduce_rand)
print()

#MAPE
mape_reduce_rand = np.average(np.abs((y_test - predictions_rand) / y_test))
print("MAPE:", mape_reduce_rand)
print()

AUC_reduce_rand = AUC(np.array(y_test), predictions_rand)
print("AUC test:", AUC_reduce_rand )
# Out:
# RMSE: 653.1159624148331
#
# MAPE: 0.016842862317252783
#
# AUC test: 0.4157509157509158

# %% [markdown]
# ## Summary statistical table

# %% [markdown]
# ### Randomized Search

# %%
def print_results_rand(AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time, 
                       AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time):
    headers = ['Type', 'Number of Features','Accuracy', 'RMSE', 'MAPE', 'Run Time (s)']
    all_results = [['All', len(importances_rand), AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time],
                   ['Reduce', len(important_feature_names_rand), AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time]]

    # Calculate the maximum width for each column
    col_widths = [max(len(str(row[i])) for row in all_results + [headers]) for i in range(len(headers))]

    # Print table headers
    header_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    print(header_format.format(*headers))

    # Print separator row
    separator = '-' * (sum(col_widths) + 3 * (len(col_widths) - 1))
    print(separator)

    # Print table rows
    row_format = '  '.join(f"{{:<{width}}}" for width in col_widths)
    for result in all_results:
        index, num_features, AUC, rmse, mape, run_time = result
        print(row_format.format(index, num_features, AUC, rmse, mape, run_time))
        
print_results_rand(AUC_all_rand, rmse_all_rand, mape_all_rand, all_rand_run_time, 
                       AUC_reduce_rand, rmse_reduce_rand, mape_reduce_rand, reduce_rand_run_time)
# Out:
# Type    Number of Features  Accuracy            RMSE                MAPE                  Run Time (s)
# -----------------------------------------------------------------------------------------------------------------
# All     23                  0.4816849816849817  1046.6956627869145  0.02748503356280206   4.049573183059692
# Reduce  2                   0.4157509157509158  653.1159624148331   0.016842862317252783  0.6896388530731201

# %% [markdown]
# # Graph Predicted Values with Test Set

# %% [markdown]
# ### Randomized Search

# %%
#hien thi ket qua du doan
fig, ax = plt.subplots(1, 1, figsize=(14, 5))
ax.plot(y_test, color = 'red', label="Bitcoin Price")
ax.plot(y_pred_rand, color = 'green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))  # .3f
plt.title("Random Forest Regression for Period 2")
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(25, 5))

ax.plot(total['Date'], total['BTC_close'], color='red', label="Bitcoin Price")
ax.plot(total['Date'][-len(y_train):], y_train, color='blue', label="Training Data")
ax.plot(total['Date'][:len(y_test)], y_test, color='orange', label="Test Data")
ax.plot(total['Date'][:len(y_pred)], y_pred_rand, color='green', label="Predicted Bitcoin Price", linestyle="dashed")
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x)))) # Định dạng đường trục y
plt.legend()
plt.show()

# %% [markdown]
# ## Comparing randomized search for hyperparameter estimation

# %%
import numpy as np

from time import time
import scipy.stats as stats
from sklearn.utils.fixes import loguniform

from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.datasets import load_digits
from sklearn.linear_model import SGDClassifier


# Utility function to report best scores
def report(results, n_top=10):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results["rank_test_score"] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print(
                "Mean validation score: {0:.3f} (std: {1:.3f})".format(
                    results["mean_test_score"][candidate],
                    results["std_test_score"][candidate],
                )
            )
            print("Parameters: {0}".format(results["params"][candidate]))
            print("")

# %% [markdown]
# #### Randomized Search

# %%
print((len(rf_random.cv_results_["params"])))
report(rf_random.cv_results_)
# Out:
# 10
# Model with rank: 1
# Mean validation score: -1541352.992 (std: 1459538.173)
# Parameters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': 6, 'criterion': 'squared_error', 'bootstrap': False}
#
# Model with rank: 2
# Mean validation score: -1834733.778 (std: 1832299.138)
# Parameters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': None, 'max_depth': 10, 'criterion': 'squared_error', 'bootstrap': True}
#
# Model with rank: 3
# Mean validation score: -4636779.894 (std: 4158082.999)
# Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error', 'bootstrap': False}
#
# Model with rank: 4
# Mean validation score: -5028957.538 (std: 5325755.416)
# Parameters: {'n_estimators': 500, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 10, 'criterion': 'squared_error', 'bootstrap': True}
#
# Model with rank: 5
# Mean validation score: -5193984.485 (std: 5404785.129)
# Parameters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 10, 'criterion': 'squared_error', 'bootstrap': True}
#
# Model with rank: 6
# Mean validation score: -5438010.589 (std: 4936716.149)
# Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 6, 'criterion': 'squared_error', 'bootstrap': True}
#
# Model with rank: 7
# Mean validation score: -7055890.321 (std: 6059548.167)
# Parameters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 4, 'criterion': 'squared_error', 'bootstrap': True}
#
# Model with rank: 8
# Mean validation score: -16634793.725 (std: 12724948.844)
# Parameters: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'squared_error', 'bootstrap': False}
#
# Model with rank: 9
# Mean validation score: -17075233.789 (std: 13079407.030)
# Parameters: {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'squared_error', 'bootstrap': False}
#
# Model with rank: 10
# Mean validation score: -17861580.289 (std: 13924079.662)
# Parameters: {'n_estimators': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'squared_error', 'bootstrap': False}

# %%
#the parameters used in the RandomForestRegressor model
print(rf.get_params())
# Out:
# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': None, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': None, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# # Summary
#
# | Metric     | DEFAULT | TUNING | NORMAL |
# | ---------- | ------- | ------ | ------ |
# | RMSE(min)  | 1433.40 | 1459.47| 1495.26|
# | MAPE%(min) | 0.06    | 0.06   | 0.06   |
# | AUC/DA ~ 1 | 0.72    | 0.79   | 0.76   |

# %%
#Default
RandomForestRegressor(bootstrap = True, ccp_alpha = 0.0, criterion = 'squared_error' , max_depth = None, 
                      max_features = 1.0, max_leaf_nodes = None, max_samples = None, 
                      min_impurity_decrease = 0.0, min_samples_leaf = 1, min_samples_split = 2, 
                      min_weight_fraction_leaf = 0.0, n_estimators = 100, n_jobs = None, oob_score = False,
                      random_state = None, verbose = 0, warm_start = False)

#or you can write shorter
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %%
#Tuning & Normalization
RandomForestRegressor(n_estimators = 600, min_samples_split = 2, min_samples_leaf = 1,
                      max_features = None, max_depth = 20, criterion = 'squared_error', bootstrap = True)
# Out:
# RandomForestRegressor(max_depth=20, max_features=None, n_estimators=600)
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=8, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   4.9s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=8, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   6.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=8, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.1s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time= 1.4min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time= 1.0min
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  27.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.8s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.4s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  16.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  23.8s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=  56.6s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=  49.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  33.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   8.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  35.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=8, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.1s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=  54.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  24.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  24.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   9.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   8.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  34.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   8.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  35.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=8, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   7.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=  54.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time=  48.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=  10.0s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  39.0s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  20.0s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.9s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.0s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  36.2s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time= 1.4min
# [CV] END bootstrap=False, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  23.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  53.9s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  18.9s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   7.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.4s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  16.4s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  23.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time= 1.4min
# [CV] END bootstrap=True, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  58.8s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=16, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=  28.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.8s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.4s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  36.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time= 1.4min
# [CV] END bootstrap=False, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  23.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  53.5s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  19.4s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   7.7s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=6, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   6.4s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=20, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  38.6s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=12, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=900; total time= 1.4min
# [CV] END bootstrap=False, criterion=squared_error, max_depth=4, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  24.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=14, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=1000; total time=  53.3s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=600; total time=  17.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.2s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=4, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   3.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   2.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.4s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   8.6s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=None, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   5.5s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=400; total time=   1.1s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END bootstrap=True, criterion=squared_error, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=10, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=False, criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=300; total time=   0.7s

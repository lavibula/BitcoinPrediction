# %% [markdown]
# Link github: https://github.com/buianhkiet110703/REGRESSION/blob/main/Final_test_regression.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from scipy.stats import norm

# %%
df= pd.read_excel(r'C:\Users\Dell\Downloads\Sample_Superstore.xlsx', sheet_name='Fact_Orders')

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df['order-ship'] = (pd.to_datetime(df['Ship Date']) - pd.to_datetime(df['Order Date'])).dt.days

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#    Discount    Profit  order-ship
# 0      0.00   41.9136           3
# 1      0.00  219.5820           3
# 2      0.00    6.8714           4
# 3      0.45 -383.0310           7
# 4      0.20    2.5164           7
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(12,6))
plt.hist(df['Profit'], bins=20, rwidth= 0.8, density=True)
plt.xlabel('Profit')
plt.ylabel('count')

rng= np.arange(df['Profit'].min(), df['Profit'].max(),0.1)
plt.plot(rng, norm.pdf(rng, df['Profit'].mean(), df['Profit'].std()));
plt.grid(True)

# %%
fig, axes = plt.subplots(2, 2, figsize=(20, 10))
sns.set(rc={'axes.facecolor':'lightblue','figure.facecolor':'mediumspringgreen'})
sns.scatterplot(ax=axes[0, 0], data=df, x='Sales', y='Profit', s=200, alpha=0.7)
axes[0,0].set_title('correlation between variable Profit and Sales')
sns.scatterplot(ax=axes[0, 1], data=df, x='Quantity', y='Profit',s=200, alpha=0.7)
axes[0,1].set_title('correlation between variable Profit and Quantity')
sns.scatterplot(ax=axes[1, 0], data=df, x='Discount', y='Profit',s=200, alpha=0.7)
axes[1,0].set_title('correlation between variable Profit and Discount')
sns.scatterplot(ax=axes[1, 1], data=df, x='order-ship', y='Profit',s=200, alpha=0.7)
axes[1,1].set_title('correlation between variable Profit and order-ship');

# %%
plt.figure(figsize=(20,10))
plt.title('CORRELATION ')
corr1= df.corr()
sns.heatmap(corr1, square= True, annot= True, fmt= '.2f', annot_kws= {'size':16}, cmap='Blues', linecolor='white', linewidths=0.5);

# %%
import plotly.express as px
fig = px.scatter(df, x = 'Sales', y ='Profit',
                   size='Sales'  , color = 'Segment')
fig.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df, x='Segment',y='Sales',hue='Category');

# %%
# xóa những dong có id
data= df.drop(['Row ID','Order ID','Order Date','Ship Date','Customer ID','Product ID','Customer Name','City', 'Postal Code','Country','Product Name','Sub-Category','State'], axis= 'columns')

# %%
data.head()
# Out:
#         Ship Mode    Segment Region         Category     Sales  Quantity  \
# 0    Second Class   Consumer  South        Furniture  261.9600         2
# 1    Second Class   Consumer  South        Furniture  731.9400         3
# 2    Second Class  Corporate   West  Office Supplies   14.6200         2
# 3  Standard Class   Consumer  South        Furniture  957.5775         5
# 4  Standard Class   Consumer  South  Office Supplies   22.3680         2
#
#    Discount    Profit  order-ship
# 0      0.00   41.9136           3
# 1      0.00  219.5820           3
# 2      0.00    6.8714           4
# 3      0.45 -383.0310           7
# 4      0.20    2.5164           7

# %% [markdown]
# # Data processing

# %%
df1= data.drop(['Profit'], axis='columns')
x= df1.values
y= data['Profit'].values

# %%
df1
# Out:
#            Ship Mode    Segment Region         Category     Sales  Quantity  \
# 0       Second Class   Consumer  South        Furniture  261.9600         2
# 1       Second Class   Consumer  South        Furniture  731.9400         3
# 2       Second Class  Corporate   West  Office Supplies   14.6200         2
# 3     Standard Class   Consumer  South        Furniture  957.5775         5
# 4     Standard Class   Consumer  South  Office Supplies   22.3680         2
# ...              ...        ...    ...              ...       ...       ...
# 9989    Second Class   Consumer  South        Furniture   25.2480         3
# 9990  Standard Class   Consumer   West        Furniture   91.9600         2
# 9991  Standard Class   Consumer   West       Technology  258.5760         2
# 9992  Standard Class   Consumer   West  Office Supplies   29.6000         4
# 9993    Second Class   Consumer   West  Office Supplies  243.1600         2
#
#       Discount  order-ship
# 0         0.00           3
# 1         0.00           3
# 2         0.00           4
# 3         0.45           7
# 4         0.20           7
# ...        ...         ...
# 9989      0.20           2
# 9990      0.00           5
# 9991      0.20           5
# 9992      0.00           5
# 9993      0.00           5
#
# [9994 rows x 8 columns]

# %%
x
# Out:
# array([['Second Class', 'Consumer', 'South', ..., 261.96, 2, 0.0],
#        ['Second Class', 'Consumer', 'South', ..., 731.9399999999999, 3,
#         0.0],
#        ['Second Class', 'Corporate', 'West', ..., 14.62, 2, 0.0],
#        ...,
#        ['Standard Class', 'Consumer', 'West', ..., 258.576, 2, 0.2],
#        ['Standard Class', 'Consumer', 'West', ..., 29.6, 4, 0.0],
#        ['Second Class', 'Consumer', 'West', ..., 243.16, 2, 0.0]],
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
mn= MinMaxScaler(feature_range=(0,1))
x[:, 4:]= mn.fit_transform(x[:,4:])

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
ohe= make_column_transformer((OneHotEncoder(),[0,1,2,3]), remainder= 'passthrough')
x= ohe.fit_transform(x)

# %% [markdown]
# # Split training and testing

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size =0.2, random_state=0)

# %%
from sklearn.linear_model import  LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import  SVR
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import SCORERS, mean_absolute_error, mean_squared_error, r2_score
models= [LinearRegression(),RandomForestRegressor(n_estimators=5),GradientBoostingRegressor(learning_rate=0.03, random_state=0),
         AdaBoostRegressor(learning_rate=0.05),
         DecisionTreeRegressor(random_state=0, max_depth=3),
         SVR(kernel='linear', gamma='scale',degree=4),KNeighborsRegressor(n_neighbors=2), 
         xgb.XGBRegressor(learning_rate=0.01), lgb.LGBMRegressor(learning_rate=0.05)];
CV = 10 
entries = []
i=0
for model in models:
    mae_l = []
    mse_l = []
    score= []
    for j in range(CV):
        model_name = model.__class__.__name__
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        score_model= model.score(X_test,y_test) 
        r2_models= r2_score(y_test,y_pred)
        score.append(score_model)
        mae_l.append(mae)
        mse_l.append(mse)
    entries.append([model_name, np.array(mae_l).mean(),np.array(mse_l).mean(),np.array(score).mean()])
    i += 1
model_df = pd.DataFrame(entries, columns=['model_name', 'Mean MAE','Mean MSE','score'])
model_df.sort_values(by=['score'], ascending=False)
# Out:
#                   model_name   Mean MAE      Mean MSE     score
# 2  GradientBoostingRegressor  42.055103  22704.075360  0.739266
# 1      RandomForestRegressor  31.832829  25605.650051  0.705944
# 7               XGBRegressor  39.721166  36718.765172  0.578321
# 8              LGBMRegressor  31.265748  38140.541844  0.561994
# 3          AdaBoostRegressor  64.657152  38504.957518  0.557809
# 4      DecisionTreeRegressor  62.417141  39300.716705  0.548670
# 0           LinearRegression  61.988581  56313.767646  0.353292
# 6        KNeighborsRegressor  63.576718  74250.230698  0.147310
# 5                        SVR  62.708889  85802.987948  0.014638

# %% [markdown]
# # Use GridSearchCV find the best parameters for model.

# %%
#GridSearchCV for RandomForestRegressor model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
parameter_RandomForestRegressor= {
    'n_estimators': range(1,20)
    }

grid_RandomForestRegressor= GridSearchCV(RandomForestRegressor(random_state=0), parameter_RandomForestRegressor, cv=5,verbose=2, refit=True )
grid_RandomForestRegressor.fit(X_train, y_train)
print('Best parameter_RandomForestRegressor: ',grid_RandomForestRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 19 candidates, totalling 95 fits
# [CV] END .....................................n_estimators=1; total time=   0.0s
# [CV] END .....................................n_estimators=1; total time=   0.0s
# [CV] END .....................................n_estimators=1; total time=   0.0s
# [CV] END .....................................n_estimators=1; total time=   0.0s
# [CV] END .....................................n_estimators=1; total time=   0.0s
# [CV] END .....................................n_estimators=2; total time=   0.0s
# [CV] END .....................................n_estimators=2; total time=   0.0s
# [CV] END .....................................n_estimators=2; total time=   0.0s
# [CV] END .....................................n_estimators=2; total time=   0.0s
# [CV] END .....................................n_estimators=2; total time=   0.0s
# [CV] END .....................................n_estimators=3; total time=   0.0s
# [CV] END .....................................n_estimators=3; total time=   0.0s
# [CV] END .....................................n_estimators=3; total time=   0.0s
# [CV] END .....................................n_estimators=3; total time=   0.0s
# [CV] END .....................................n_estimators=3; total time=   0.0s
# [CV] END .....................................n_estimators=4; total time=   0.0s
# [CV] END .....................................n_estimators=4; total time=   0.0s
# [CV] END .....................................n_estimators=4; total time=   0.0s
# [CV] END .....................................n_estimators=4; total time=   0.0s
# [CV] END .....................................n_estimators=4; total time=   0.0s
# [CV] END .....................................n_estimators=5; total time=   0.0s
# [CV] END .....................................n_estimators=5; total time=   0.0s
# [CV] END .....................................n_estimators=5; total time=   0.0s
# [CV] END .....................................n_estimators=5; total time=   0.0s
# [CV] END .....................................n_estimators=5; total time=   0.0s
# [CV] END .....................................n_estimators=6; total time=   0.0s
# [CV] END .....................................n_estimators=6; total time=   0.0s
# [CV] END .....................................n_estimators=6; total time=   0.0s
# [CV] END .....................................n_estimators=6; total time=   0.0s
# [CV] END .....................................n_estimators=6; total time=   0.0s
# [CV] END .....................................n_estimators=7; total time=   0.1s
# [CV] END .....................................n_estimators=7; total time=   0.0s
# [CV] END .....................................n_estimators=7; total time=   0.0s
# [CV] END ....................................n_estimators=18; total time=   0.2s
# [CV] END ....................................n_estimators=19; total time=   0.3s
# [CV] END ....................................n_estimators=19; total time=   0.2s
# [CV] END ....................................n_estimators=19; total time=   0.3s
# [CV] END ....................................n_estimators=19; total time=   0.3s
# [CV] END ....................................n_estimators=19; total time=   0.2s
# Best parameter_RandomForestRegressor:  {'n_estimators': 12}

# %%
# GridSearchCV for DecisionTreeRegressor model
from sklearn.tree import DecisionTreeRegressor
parameter_DecisionTreeRegressor= {
    'max_depth': range(1,50)
}
grid_DecisionTreeRegressor= GridSearchCV(DecisionTreeRegressor(), parameter_DecisionTreeRegressor, cv=5,verbose=2, refit=True )
grid_DecisionTreeRegressor.fit(X_train, y_train)
print('Best parameter_DecisionTreeRegressor: ',grid_DecisionTreeRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END ........................................max_depth=9; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth=10; total time=   0.0s
# [CV] END .......................................max_depth
# [CV] END .......................................max_depth=47; total time=   0.0s
# [CV] END .......................................max_depth=47; total time=   0.0s
# [CV] END .......................................max_depth=47; total time=   0.0s
# [CV] END .......................................max_depth=48; total time=   0.0s
# [CV] END .......................................max_depth=48; total time=   0.0s
# [CV] END .......................................max_depth=48; total time=   0.0s
# [CV] END .......................................max_depth=48; total time=   0.0s
# [CV] END .......................................max_depth=48; total time=   0.0s
# [CV] END .......................................max_depth=49; total time=   0.0s
# [CV] END .......................................max_depth=49; total time=   0.0s
# [CV] END .......................................max_depth=49; total time=   0.0s
# [CV] END .......................................max_depth=49; total time=   0.0s
# [CV] END .......................................max_depth=49; total time=   0.0s
# Best parameter_DecisionTreeRegressor:  {'max_depth': 7}

# %%
# GridSearchCV for KNeighborsRegressor model
from sklearn.neighbors import KNeighborsRegressor
parameter_KNeighborsRegressor= {
    'n_neighbors': range(1,50)
}
grid_NeighborsRegressor= GridSearchCV(KNeighborsRegressor(), parameter_KNeighborsRegressor, cv=5,verbose=2, refit=True )
grid_NeighborsRegressor.fit(X_train, y_train)
print('Best parameter_KNeighborsRegressor: ', grid_NeighborsRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=1; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=2; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=4; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=6; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END .....................................n_neighbors=40; total time=   0.0s
# [CV] END .....................................n_neighbors=40; total time=   0.0s
# [CV] END .....................................n_neighbors=40; total time=   0.0s
# [CV] END .....................................n_neighbors=41; total time=   0.0s
# [CV] END .....................................n_neighbors=41; total time=   0.0s
# [CV] END .....................................n_neighbors=41; total time=   0.0s
# [CV] END .....................................n_neighbors=41; total time=   0.0s
# [CV] END .....................................n_neighbors=41; total time=   0.0s
# [CV] END .....................................n_neighbors=42; total time=   0.0s
# [CV] END .....................................n_neighbors=42; total time=   0.0s
# [CV] END .....................................n_neighbors=42; total time=   0.0s
# [CV] END .....................................n_neighbors=42; total time=   0.0s
# [CV] END .....................................n_neighbors=42; total time=   0.0s
# [CV] END .....................................n_neighbors=43; total time=   0.0s
# [CV] END .....................................n_neighbors=43; total time=   0.0s
# [CV] END .....................................n_neighbors=43; total time=   0.0s
# [CV] END .....................................n_neighbors=43; total time=   0.0s
# [CV] END .....................................n_neighbors=43; total time=   0.0s
# [CV] END .....................................n_neighbors=44; total time=   0.0s
# [CV] END .....................................n_neighbors=44; total time=   0.0s
# [CV] END .....................................n_neighbors=44; total time=   0.0s
# [CV] END .....................................n_neighbors=44; total time=   0.0s
# [CV] END .....................................n_neighbors=44; total time=   0.0s
# [CV] END .....................................n_neighbors=45; total time=   0.0s
# [CV] END .....................................n_neighbors=45; total time=   0.0s
# [CV] END .....................................n_neighbors=45; total time=   0.0s
# [CV] END .....................................n_neighbors=45; total time=   0.0s
# [CV] END .....................................n_neighbors=45; total time=   0.0s
# [CV] END .....................................n_neighbors=46; total time=   0.0s
# [CV] END .....................................n_neighbors=46; total time=   0.0s
# [CV] END .....................................n_neighbors=46; total time=   0.0s
# [CV] END .....................................n_neighbors=46; total time=   0.0s
# [CV] END .....................................n_neighbors=46; total time=   0.0s
# [CV] END .....................................n_neighbors=47; total time=   0.0s
# [CV] END .....................................n_neighbors=47; total time=   0.0s
# [CV] END .....................................n_neighbors=47; total time=   0.0s
# [CV] END .....................................n_neighbors=47; total time=   0.0s
# [CV] END .....................................n_neighbors=47; total time=   0.0s
# [CV] END .....................................n_neighbors=48; total time=   0.0s
# [CV] END .....................................n_neighbors=48; total time=   0.0s
# [CV] END .....................................n_neighbors=48; total time=   0.0s
# [CV] END .....................................n_neighbors=48; total time=   0.0s
# [CV] END .....................................n_neighbors=48; total time=   0.0s
# [CV] END .....................................n_neighbors=49; total time=   0.0s
# [CV] END .....................................n_neighbors=49; total time=   0.0s
# [CV] END .....................................n_neighbors=49; total time=   0.0s
# [CV] END .....................................n_neighbors=49; total time=   0.0s
# [CV] END .....................................n_neighbors=49; total time=   0.0s
# Best parameter_KNeighborsRegressor:  {'n_neighbors': 7}

# %%
# GridSearchCV for GradientBoostingRegressor model
from sklearn.ensemble import GradientBoostingRegressor
parameter_GradientBoostingRegressor= {
    'learning_rate': [0.03,0.05],
    'max_depth' : [5,10,12,15,20],
    'n_estimators' :[10,15,20,100,1000]
}
grid_GradientBoostingRegressor= GridSearchCV(GradientBoostingRegressor(), parameter_GradientBoostingRegressor, cv=5,verbose=2, refit=True )
grid_GradientBoostingRegressor.fit(X_train, y_train)
print('Best parameter_GradientBoostingRegressor: ', grid_GradientBoostingRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.03, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END ..learning_rate=0.03, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.03, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.03, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.03, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.03, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END .learning_rate=0.03, max_depth=5, n_estimators=1000; total time=   8.2s
# [CV] END .learning_rate=0.03, max_depth=5, n_estimators=1000; total time=   8.3s
# [CV] END .learning_rate=0.03, max_depth=5, n_estimators=1000; total time=   8.4s
# [CV] END .learning_rate=0.03, max_depth=5, n_estimators=1000; total time=   7.9s
# [CV] END .learning_rate=0.03, max_depth=5, n_estimators=1000; total time=   7.4s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END .learning_rate=0.03, max_depth=10, n_estimators=100; total time=   1.4s
# [CV] END .learning_rate=0.03, max_depth=10, n_estimators=100; total time=   1.3s
# [CV] END .learning_rate=0.03, max_depth=10, n_estimators=100; total time=   1.3s
# [CV] END .learning_rate=0.03, max_depth=10, n_estimators=100; total time=   1.3s
# [CV] END .learning_rate=0.03, max_depth=10, n_estimators=100; total time=   1.3s
# [CV] END learning_rate=0.03, max_depth=10, n_estimators=1000; total time=  13.8s
# [CV] END learning_rate=0.03, max_depth=10, n_estimators=1000; total time=  14.0s
# [CV] END learning_rate=0.03, max_depth=10, n_estimators=1000; total time=  13.8s
# [CV] END learning_rate=0.03, max_depth=10, n_estimators=1000; total time=  14.0s
# [CV] END learning_rate=0.03, max_depth=10, n_estimators=1000; total time=  14.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END .learning_rate=0.03, max_depth=12, n_estimators=100; total time=   1.5s
# [CV] END .learning_rate=0.03, max_depth=12, n_estimators=100; total time=   1.6s
# [CV] END .learning_rate=0.03, max_depth=12, n_estimators=100; total time=   1.6s
# [CV] END .learning_rate=0.03, max_depth=12, n_estimators=100; total time=   1.6s
# [CV] END .learning_rate=0.03, max_depth=12, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.03, max_depth=12, n_estimators=1000; total time=  16.3s
# [CV] END learning_rate=0.03, max_depth=12, n_estimators=1000; total time=  16.5s
# [CV] END learning_rate=0.03, max_depth=12, n_estimators=1000; total time=  16.6s
# [CV] END learning_rate=0.03, max_depth=12, n_estimators=1000; total time=  16.6s
# [CV] END learning_rate=0.03, max_depth=12, n_estimators=1000; total time=  16.4s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=20; total time=   0.4s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END .learning_rate=0.03, max_depth=15, n_estimators=100; total time=   2.0s
# [CV] END .learning_rate=0.03, max_depth=15, n_estimators=100; total time=   1.9s
# [CV] END .learning_rate=0.03, max_depth=15, n_estimators=100; total time=   2.0s
# [CV] END .learning_rate=0.03, max_depth=15, n_estimators=100; total time=   2.0s
# [CV] END .learning_rate=0.03, max_depth=15, n_estimators=100; total time=   2.0s
# [CV] END learning_rate=0.03, max_depth=15, n_estimators=1000; total time=  20.0s
# [CV] END learning_rate=0.03, max_depth=15, n_estimators=1000; total time=  19.9s
# [CV] END learning_rate=0.03, max_depth=15, n_estimators=1000; total time=  20.4s
# [CV] END learning_rate=0.03, max_depth=15, n_estimators=1000; total time=  20.8s
# [CV] END learning_rate=0.03, max_depth=15, n_estimators=1000; total time=  20.9s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.03, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END .learning_rate=0.03, max_depth=20, n_estimators=100; total time=   2.7s
# [CV] END .learning_rate=0.03, max_depth=20, n_estimators=100; total time=   2.9s
# [CV] END .learning_rate=0.03, max_depth=20, n_estimators=100; total time=   2.8s
# [CV] END .learning_rate=0.03, max_depth=20, n_estimators=100; total time=   3.1s
# [CV] END .learning_rate=0.03, max_depth=20, n_estimators=100; total time=   3.0s
# [CV] END learning_rate=0.03, max_depth=20, n_estimators=1000; total time=  28.9s
# [CV] END learning_rate=0.03, max_depth=20, n_estimators=1000; total time=  28.4s
# [CV] END learning_rate=0.03, max_depth=20, n_estimators=1000; total time=  26.6s
# [CV] END learning_rate=0.03, max_depth=20, n_estimators=1000; total time=  26.3s
# [CV] END learning_rate=0.03, max_depth=20, n_estimators=1000; total time=  27.4s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=15; total time=   0.0s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ...learning_rate=0.05, max_depth=5, n_estimators=20; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.6s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END ..learning_rate=0.05, max_depth=5, n_estimators=100; total time=   0.7s
# [CV] END .learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   7.5s
# [CV] END .learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   7.2s
# [CV] END .learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   7.7s
# [CV] END .learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   7.9s
# [CV] END .learning_rate=0.05, max_depth=5, n_estimators=1000; total time=   7.5s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=15; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=10, n_estimators=20; total time=   0.2s
# [CV] END .learning_rate=0.05, max_depth=10, n_estimators=100; total time=   1.3s
# [CV] END .learning_rate=0.05, max_depth=10, n_estimators=100; total time=   1.4s
# [CV] END .learning_rate=0.05, max_depth=10, n_estimators=100; total time=   1.4s
# [CV] END .learning_rate=0.05, max_depth=10, n_estimators=100; total time=   1.4s
# [CV] END .learning_rate=0.05, max_depth=10, n_estimators=100; total time=   1.5s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  14.4s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  14.1s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  14.0s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  13.8s
# [CV] END learning_rate=0.05, max_depth=10, n_estimators=1000; total time=  14.8s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=12, n_estimators=20; total time=   0.2s
# [CV] END .learning_rate=0.05, max_depth=12, n_estimators=100; total time=   1.6s
# [CV] END .learning_rate=0.05, max_depth=12, n_estimators=100; total time=   1.7s
# [CV] END .learning_rate=0.05, max_depth=12, n_estimators=100; total time=   1.8s
# [CV] END .learning_rate=0.05, max_depth=12, n_estimators=100; total time=   1.8s
# [CV] END .learning_rate=0.05, max_depth=12, n_estimators=100; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=12, n_estimators=1000; total time=  17.3s
# [CV] END learning_rate=0.05, max_depth=12, n_estimators=1000; total time=  16.9s
# [CV] END learning_rate=0.05, max_depth=12, n_estimators=1000; total time=  17.2s
# [CV] END learning_rate=0.05, max_depth=12, n_estimators=1000; total time=  17.2s
# [CV] END learning_rate=0.05, max_depth=12, n_estimators=1000; total time=  17.0s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=10; total time=   0.1s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=15; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=15, n_estimators=20; total time=   0.3s
# [CV] END .learning_rate=0.05, max_depth=15, n_estimators=100; total time=   2.0s
# [CV] END .learning_rate=0.05, max_depth=15, n_estimators=100; total time=   2.1s
# [CV] END .learning_rate=0.05, max_depth=15, n_estimators=100; total time=   2.2s
# [CV] END .learning_rate=0.05, max_depth=15, n_estimators=100; total time=   2.1s
# [CV] END .learning_rate=0.05, max_depth=15, n_estimators=100; total time=   2.0s
# [CV] END learning_rate=0.05, max_depth=15, n_estimators=1000; total time=  21.0s
# [CV] END learning_rate=0.05, max_depth=15, n_estimators=1000; total time=  20.0s
# [CV] END learning_rate=0.05, max_depth=15, n_estimators=1000; total time=  21.0s
# [CV] END learning_rate=0.05, max_depth=15, n_estimators=1000; total time=  21.2s
# [CV] END learning_rate=0.05, max_depth=15, n_estimators=1000; total time=  21.3s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=10; total time=   0.2s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=15; total time=   0.3s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=20; total time=   0.5s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=20; total time=   0.4s
# [CV] END ..learning_rate=0.05, max_depth=20, n_estimators=20; total time=   0.4s
# [CV] END .learning_rate=0.05, max_depth=20, n_estimators=100; total time=   2.6s
# [CV] END .learning_rate=0.05, max_depth=20, n_estimators=100; total time=   2.8s
# [CV] END .learning_rate=0.05, max_depth=20, n_estimators=100; total time=   2.7s
# [CV] END .learning_rate=0.05, max_depth=20, n_estimators=100; total time=   2.7s
# [CV] END .learning_rate=0.05, max_depth=20, n_estimators=100; total time=   2.7s
# [CV] END learning_rate=0.05, max_depth=20, n_estimators=1000; total time=  27.9s
# [CV] END learning_rate=0.05, max_depth=20, n_estimators=1000; total time=  27.8s
# [CV] END learning_rate=0.05, max_depth=20, n_estimators=1000; total time=  27.0s
# [CV] END learning_rate=0.05, max_depth=20, n_estimators=1000; total time=  28.4s
# [CV] END learning_rate=0.05, max_depth=20, n_estimators=1000; total time=  26.5s
# Best parameter_GradientBoostingRegressor:  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 1000}

# %%
# GridSearchCV for XGBRegressor model
import xgboost as xgb
parameter_XGBRegressor= {
    'max_depth': [5,7,10,20],
    'n_estimators' :[20,100,1000],
    'subsample': [0.5,0.7,0.8]
}
grid_XGBRegressor= GridSearchCV(xgb.XGBRegressor(), parameter_XGBRegressor, cv=5,verbose=2, refit=True )
grid_XGBRegressor.fit(X_train, y_train)
print('Best parameter_XGBRegressor: ', grid_XGBRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=5, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END .......max_depth=5, n_estimators=100, subsample=0.8; total time=   0.2s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.5; total time=   2.4s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.5; total time=   2.4s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.5; total time=   2.3s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.5; total time=   2.4s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.5; total time=   2.4s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.7; total time=   2.6s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.7; total time=   2.6s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.7; total time=   2.6s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.7; total time=   2.7s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.7; total time=   2.8s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.9s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.8; total time=   3.0s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.7s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.7s
# [CV] END ......max_depth=5, n_estimators=1000, subsample=0.8; total time=   2.8s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ........max_depth=7, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.5; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.7; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.8; total time=   0.4s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END .......max_depth=7, n_estimators=100, subsample=0.8; total time=   0.3s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.5; total time=   3.5s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.5; total time=   3.6s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.5; total time=   4.0s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.5; total time=   4.1s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.5; total time=   3.6s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.7; total time=   3.8s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.7; total time=   3.8s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.7; total time=   4.0s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.7; total time=   4.0s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.7; total time=   4.1s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.8; total time=   3.9s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.8; total time=   4.0s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.8; total time=   3.8s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.8; total time=   3.9s
# [CV] END ......max_depth=7, n_estimators=1000, subsample=0.8; total time=   3.9s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.5; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.7; total time=   0.1s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.7; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END .......max_depth=10, n_estimators=20, subsample=0.8; total time=   0.0s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.5; total time=   0.4s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.7; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.7; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.7; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.7; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.7; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END ......max_depth=10, n_estimators=100, subsample=0.8; total time=   0.5s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.5; total time=   6.3s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.5; total time=   6.2s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.5; total time=   6.3s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.5; total time=   7.7s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.5; total time=   6.2s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.7; total time=   7.0s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.7; total time=   7.3s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.7; total time=   6.5s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.7; total time=   7.2s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.7; total time=   7.6s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.8; total time=   7.3s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.8; total time=   7.2s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.8; total time=   6.6s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.8; total time=   7.2s
# [CV] END .....max_depth=10, n_estimators=1000, subsample=0.8; total time=   7.5s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.5; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.5; total time=   0.1s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.7; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.8; total time=   0.3s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.8; total time=   0.3s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.8; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.8; total time=   0.2s
# [CV] END .......max_depth=20, n_estimators=20, subsample=0.8; total time=   0.2s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.5; total time=   1.2s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.5; total time=   1.2s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.5; total time=   1.1s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.5; total time=   1.1s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.5; total time=   1.1s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.7; total time=   1.5s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.7; total time=   1.7s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.7; total time=   1.7s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.7; total time=   1.6s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.7; total time=   1.5s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.8; total time=   1.8s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.8; total time=   1.7s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.8; total time=   1.6s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.8; total time=   1.6s
# [CV] END ......max_depth=20, n_estimators=100, subsample=0.8; total time=   1.6s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.5; total time=  13.0s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.5; total time=  14.7s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.5; total time=  12.5s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.5; total time=  14.8s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.5; total time=  14.6s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.7; total time=  10.2s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.7; total time=  13.2s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.7; total time=   8.9s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.7; total time=  12.0s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.7; total time=  12.6s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.8; total time=   8.2s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.8; total time=   8.4s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.8; total time=   7.4s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.8; total time=   8.6s
# [CV] END .....max_depth=20, n_estimators=1000, subsample=0.8; total time=   9.6s
# Best parameter_XGBRegressor:  {'max_depth': 5, 'n_estimators': 100, 'subsample': 0.8}

# %%
# GridSearchCV for SVR model
from sklearn.svm import SVR
parameter_SVR= {
    'kernel': [ 'poly','linear'],
    'degree': [3,4],
    'gamma': ['scale','auto']
    }
grid_SVR= GridSearchCV(SVR(), parameter_SVR, cv=5,verbose=2, refit=True )
grid_SVR.fit(X_train, y_train)
print('Best parameter_SVR: ', grid_SVR.best_params_ )
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV] END .................degree=3, gamma=scale, kernel=poly; total time=   1.5s
# [CV] END .................degree=3, gamma=scale, kernel=poly; total time=   1.6s
# [CV] END .................degree=3, gamma=scale, kernel=poly; total time=   1.6s
# [CV] END .................degree=3, gamma=scale, kernel=poly; total time=   1.5s
# [CV] END .................degree=3, gamma=scale, kernel=poly; total time=   1.5s
# [CV] END ...............degree=3, gamma=scale, kernel=linear; total time=   1.5s
# [CV] END ...............degree=3, gamma=scale, kernel=linear; total time=   1.5s
# [CV] END ...............degree=3, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END ...............degree=3, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END ...............degree=3, gamma=scale, kernel=linear; total time=   1.5s
# [CV] END ..................degree=3, gamma=auto, kernel=poly; total time=   1.5s
# [CV] END ..................degree=3, gamma=auto, kernel=poly; total time=   1.6s
# [CV] END ..................degree=3, gamma=auto, kernel=poly; total time=   1.5s
# [CV] END ..................degree=3, gamma=auto, kernel=poly; total time=   1.5s
# [CV] END ..................degree=3, gamma=auto, kernel=poly; total time=   1.5s
# [CV] END ................degree=3, gamma=auto, kernel=linear; total time=   1.5s
# [CV] END ................degree=3, gamma=auto, kernel=linear; total time=   1.9s
# [CV] END ................degree=3, gamma=auto, kernel=linear; total time=   1.5s
# [CV] END ................degree=3, gamma=auto, kernel=linear; total time=   1.4s
# [CV] END ................degree=3, gamma=auto, kernel=linear; total time=   1.4s
# [CV] END .................degree=4, gamma=scale, kernel=poly; total time=   1.5s
# [CV] END .................degree=4, gamma=scale, kernel=poly; total time=   1.7s
# [CV] END .................degree=4, gamma=scale, kernel=poly; total time=   1.6s
# [CV] END .................degree=4, gamma=scale, kernel=poly; total time=   1.7s
# [CV] END .................degree=4, gamma=scale, kernel=poly; total time=   1.6s
# [CV] END ...............degree=4, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END ...............degree=4, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END ...............degree=4, gamma=scale, kernel=linear; total time=   1.5s
# [CV] END ...............degree=4, gamma=scale, kernel=linear; total time=   1.4s
# [CV] END ...............degree=4, gamma=scale, kernel=linear; total time=   1.5s
# [CV] END ..................degree=4, gamma=auto, kernel=poly; total time=   1.6s
# [CV] END ..................degree=4, gamma=auto, kernel=poly; total time=   1.6s
# [CV] END ..................degree=4, gamma=auto, kernel=poly; total time=   1.6s
# [CV] END ..................degree=4, gamma=auto, kernel=poly; total time=   1.6s
# [CV] END ..................degree=4, gamma=auto, kernel=poly; total time=   1.6s
# [CV] END ................degree=4, gamma=auto, kernel=linear; total time=   1.5s
# [CV] END ................degree=4, gamma=auto, kernel=linear; total time=   1.4s
# [CV] END ................degree=4, gamma=auto, kernel=linear; total time=   1.5s
# [CV] END ................degree=4, gamma=auto, kernel=linear; total time=   1.4s
# [CV] END ................degree=4, gamma=auto, kernel=linear; total time=   1.4s
# Best parameter_SVR:  {'degree': 4, 'gamma': 'scale', 'kernel': 'poly'}

# %%
# GridSearchCV for LGBMRegressor model
import lightgbm as lgb
parameter_LGBMRegressor= {
    'max_depth': [ 5,10,20],
    'n_estimators': [100,1000,2000],
    }
grid_LGBMRegressor= GridSearchCV(lgb.LGBMRegressor(), parameter_LGBMRegressor, cv=5,verbose=2, refit=True )
grid_LGBMRegressor.fit(X_train, y_train)
print('Best parameter_LGBMRegressor: ', grid_LGBMRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ......................max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END ......................max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END .....................max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END .....................max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END .....................max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END .....................max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END .....................max_depth=5, n_estimators=2000; total time=   0.6s
# [CV] END .....................max_depth=5, n_estimators=2000; total time=   0.6s
# [CV] END .....................max_depth=5, n_estimators=2000; total time=   0.6s
# [CV] END .....................max_depth=5, n_estimators=2000; total time=   0.6s
# [CV] END .....................max_depth=5, n_estimators=2000; total time=   0.6s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=10, n_estimators=100; total time=   0.0s
# [CV] END ....................max_depth=10, n_estimators=1000; total time=   0.6s
# [CV] END ....................max_depth=10, n_estimators=1000; total time=   0.6s
# [CV] END ....................max_depth=10, n_estimators=1000; total time=   0.6s
# [CV] END ....................max_depth=10, n_estimators=1000; total time=   0.7s
# [CV] END ....................max_depth=10, n_estimators=1000; total time=   0.6s
# [CV] END ....................max_depth=10, n_estimators=2000; total time=   1.3s
# [CV] END ....................max_depth=10, n_estimators=2000; total time=   1.3s
# [CV] END ....................max_depth=10, n_estimators=2000; total time=   1.4s
# [CV] END ....................max_depth=10, n_estimators=2000; total time=   1.5s
# [CV] END ....................max_depth=10, n_estimators=2000; total time=   1.5s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.0s
# [CV] END .....................max_depth=20, n_estimators=100; total time=   0.0s
# [CV] END ....................max_depth=20, n_estimators=1000; total time=   0.7s
# [CV] END ....................max_depth=20, n_estimators=1000; total time=   0.7s
# [CV] END ....................max_depth=20, n_estimators=1000; total time=   0.8s
# [CV] END ....................max_depth=20, n_estimators=1000; total time=   0.7s
# [CV] END ....................max_depth=20, n_estimators=1000; total time=   0.7s
# [CV] END ....................max_depth=20, n_estimators=2000; total time=   1.8s
# [CV] END ....................max_depth=20, n_estimators=2000; total time=   1.5s
# [CV] END ....................max_depth=20, n_estimators=2000; total time=   1.8s
# [CV] END ....................max_depth=20, n_estimators=2000; total time=   1.7s
# [CV] END ....................max_depth=20, n_estimators=2000; total time=   1.6s
# Best parameter_LGBMRegressor:  {'max_depth': 5, 'n_estimators': 1000}

# %%
# GridSearchCV for AdaBoostRegressor model
from sklearn.ensemble import AdaBoostRegressor
parameter_AdaBoostRegressor= {
    'learning_rate':[0.05,0.08],
    'loss': ['linear', 'square','exponential'],
    'n_estimators': [50,100,1000],
    'base_estimator': [DecisionTreeRegressor(max_depth=5),DecisionTreeRegressor(max_depth=10),DecisionTreeRegressor(max_depth=20)]
    }
grid_AdaBoostRegressor= GridSearchCV(AdaBoostRegressor(), parameter_AdaBoostRegressor, cv=5,verbose=2, refit=True )
grid_AdaBoostRegressor.fit(X_train, y_train)
print('Best parameter_AdaBoostRegressor: ', grid_AdaBoostRegressor.best_params_ )
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=50; total time=   0.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=50; total time=   0.9s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=50; total time=   0.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=100; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=100; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=100; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=100; total time=   1.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=100; total time=   1.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  13.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  13.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  13.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=1000; total time=   8.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  13.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=50; total time=   0.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=50; total time=   0.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=50; total time=   0.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=100; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=100; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=100; total time=   1.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=100; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=100; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=1000; total time=  12.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=1000; total time=  13.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=1000; total time=  12.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=1000; total time=  12.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=square, n_estimators=1000; total time=  12.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   0.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   1.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   1.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   1.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   1.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  12.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  12.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  12.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  12.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  12.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=1000; total time=   4.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  11.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  11.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=1000; total time=   4.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  11.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=1000; total time=  10.9s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=1000; total time=  11.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=1000; total time=  11.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=1000; total time=  11.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=square, n_estimators=1000; total time=  11.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   0.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   0.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   1.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  11.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  11.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  11.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  11.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=5), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  12.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=50; total time=   1.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=50; total time=   1.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=50; total time=   1.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=100; total time=   2.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  18.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  18.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  18.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  18.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=linear, n_estimators=1000; total time=  19.9s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=50; total time=   1.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=100; total time=   2.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=100; total time=   2.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=1000; total time=  20.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=1000; total time=  21.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=1000; total time=  20.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=1000; total time=  20.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=square, n_estimators=1000; total time=  19.9s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   1.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   1.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   1.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   1.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   2.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   2.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   2.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   2.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   2.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  21.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  20.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  19.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  20.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  20.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=10), learning_rate=0.08, loss

# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   3.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  31.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  31.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  31.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  31.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.05, loss=exponential, n_estimators=1000; total time=  32.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=100; total time=   3.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=100; total time=   3.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=100; total time=   3.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=100; total time=   3.3s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=100; total time=   3.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  31.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  30.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  30.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  30.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=linear, n_estimators=1000; total time=  30.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=50; total time=   1.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=50; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=100; total time=   3.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=100; total time=   3.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=1000; total time=  29.6s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=1000; total time=  29.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=1000; total time=  29.7s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=1000; total time=  29.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=square, n_estimators=1000; total time=  29.4s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=50; total time=   1.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   3.1s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=100; total time=   3.2s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  30.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  37.8s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  33.5s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  30.0s
# [CV] END base_estimator=DecisionTreeRegressor(max_depth=20), learning_rate=0.08, loss=exponential, n_estimators=1000; total time=  30.1s
# Best parameter_AdaBoostRegressor:  {'base_estimator': DecisionTreeRegressor(max_depth=5), 'learning_rate': 0.05, 'loss': 'linear', 'n_estimators': 1000}

# %%
from sklearn.linear_model import  LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import  SVR
from sklearn.neighbors import KNeighborsRegressor
import xgboost as xgb                                             
import lightgbm as lgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import SCORERS, mean_absolute_error, mean_squared_error
models= [LinearRegression(),RandomForestRegressor(n_estimators=12, random_state=0),GradientBoostingRegressor(learning_rate=0.05, max_depth=5,n_estimators=1000),
         DecisionTreeRegressor(random_state=0, max_depth=7),
         SVR(kernel='linear', gamma='scale',degree=4),KNeighborsRegressor(n_neighbors=7), 
         xgb.XGBRegressor(learning_rate=0.08,max_depth=5,n_estimators=100, subsample=0.8), lgb.LGBMRegressor(learning_rate=0.05,max_depth=5,n_estimators=100),
         AdaBoostRegressor(learning_rate=0.05, base_estimator= DecisionTreeRegressor(max_depth=5),loss='linear', n_estimators=1000)] ;
CV = 10 
entries = []
i=0                                             
for model in models:
    mae_l = []
    mse_l = []
    score= []
    for j in range(CV):
        model_name = model.__class__.__name__
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mae = mean_absolute_error(y_test, y_pred)
        mse = mean_squared_error(y_test, y_pred)
        score_model= model.score(X_test,y_test) 
        score.append(score_model)
        mae_l.append(mae)
        mse_l.append(mse)
    entries.append([model_name, np.array(mae_l).mean(),np.array(mse_l).mean(),np.array(score).mean()])
    i += 1
model_df = pd.DataFrame(entries, columns=['model_name', 'Mean MAE','Mean MSE','score'])
model_df.sort_values(by=['score'], ascending=False)
# Out:
#                   model_name   Mean MAE      Mean MSE     score
# 3      DecisionTreeRegressor  31.757690  15691.547961  0.819798
# 1      RandomForestRegressor  29.515135  16050.841598  0.815672
# 2  GradientBoostingRegressor  27.986076  16788.013075  0.807206
# 6               XGBRegressor  30.765939  18365.652737  0.789089
# 8          AdaBoostRegressor  37.978149  20635.945172  0.763017
# 7              LGBMRegressor  31.371738  36028.629261  0.586247
# 0           LinearRegression  61.988581  56313.767646  0.353292
# 5        KNeighborsRegressor  65.207939  77361.845216  0.111576
# 4                        SVR  62.708889  85802.987948  0.014638

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg= PolynomialFeatures(degree=3)
x_poly= poly_reg.fit_transform(X_train)
poly_reg.fit(x_poly,y_train)
lin_reg= LinearRegression()
lin_reg.fit(x_poly,y_train)
x_test_poly= poly_reg.fit_transform(X_test)
lin_score= lin_reg.score(x_test_poly, y_test)
y_pred_poly= lin_reg.predict(x_test_poly)
lin_mse= mean_squared_error(y_test,y_pred_poly)
lin_mae= mean_absolute_error(y_test,y_pred_poly)
print('MSE_POLY: ',lin_mse)
print('MAE_POLY: ',lin_mae)
print('SCORE POLY: ',lin_score)
# Out:
# MSE_POLY:  74468.56782104826
# MAE_POLY:  39.7468176088044
# SCORE POLY:  0.14480231310700176

# %%
from sklearn.ensemble import BaggingRegressor
bg= BaggingRegressor(n_estimators=1000, max_samples=7995,random_state=0)
bg.fit(X_train,y_train)
score= bg.score(X_test,y_test)
y_pred= bg.predict(X_test)
mse= mean_squared_error(y_test,y_pred)
mae= mean_absolute_error(y_test, y_pred)
print('MSE: ', mse)
print('MAE: ', mae)
print('SCORRE: ', score)
# Out:
# MSE:  21799.12495604431
# MAE:  28.954374305427592
# SCORRE:  0.7496586575493227

# %%
from sklearn.ensemble import BaggingRegressor
model_BaggingRegressor_LinearRegression = BaggingRegressor(LinearRegression(), random_state=0)
model_BaggingRegressor_LinearRegression.fit(X_train, y_train)
score = model.score(X_test,y_test)
y_pred= model_BaggingRegressor_LinearRegression.predict(X_test)
mse= mean_squared_error(y_test,y_pred)
mae= mean_absolute_error(y_test, y_pred)
print('MSE: ', mse)
print('MAE: ', mae)
print('SCORRE: ', score)
# Out:
# MSE:  55427.37282885362
# MAE:  61.39688457431841
# SCORRE:  0.7582074315048242

# %%
model = BaggingRegressor(RandomForestRegressor(n_estimators=12), random_state=0)
model.fit(X_train,y_train)
score = model.score(X_test,y_test)
y_pred= model.predict(X_test)
mse= mean_squared_error(y_test,y_pred)
mae= mean_absolute_error(y_test, y_pred)
print('MSE: ', mse)
print('MAE: ', mae)
print('SCORRE: ', score)
# Out:
# MSE:  26937.589566463266
# MAE:  30.30115787917453
# SCORRE:  0.6906484848336101

# %%
model = BaggingRegressor(DecisionTreeRegressor(max_depth=20), random_state=0)
model.fit(X_train,y_train)
score = model.score(X_test,y_test)
y_pred= model.predict(X_test)
mse= mean_squared_error(y_test,y_pred)
mae= mean_absolute_error(y_test, y_pred)
print('MSE: ', mse)
print('MAE: ', mae)
print('SCORRE: ', score)
# Out:
# MSE:  15818.370687695025
# MAE:  29.43079687400924
# SCORRE:  0.8183416920942959

# %%
cv_df= {
 'model_name':['PolynomialFeatures(degree=3)','BaggingRegressor','BaggingRegressor(LinearRegression)',
 'BaggingRegressor(RandomForestRegressor)','BaggingRegressor(DecisionTreeRegressor)'],
 'Mean MAE':[39.707817458729366, 28.954374305427592, 61.37902788738119, 29.84634918392471,29.43079687400924],   
 'Mean MSE':[73621.49870775724, 21799.12495604431, 55438.6410992574, 27310.201803991837, 15818.370687695025],
 'score':[0.15453006224360089, 0.7496586575493227,0.014684260264121507,0.6863694026252856,0.8183416920942959]
}
df2= pd.DataFrame(cv_df)
df2
# Out:
#                                 model_name   Mean MAE      Mean MSE     score
# 0             PolynomialFeatures(degree=3)  39.707817  73621.498708  0.154530
# 1                         BaggingRegressor  28.954374  21799.124956  0.749659
# 2       BaggingRegressor(LinearRegression)  61.379028  55438.641099  0.014684
# 3  BaggingRegressor(RandomForestRegressor)  29.846349  27310.201804  0.686369
# 4  BaggingRegressor(DecisionTreeRegressor)  29.430797  15818.370688  0.818342

# %%
total= pd.concat([model_df, df2],ignore_index=True)
total.sort_values(by=['score'], ascending=False)
# Out:
#                                  model_name   Mean MAE      Mean MSE     score
# 3                     DecisionTreeRegressor  31.757690  15691.547961  0.819798
# 13  BaggingRegressor(DecisionTreeRegressor)  29.430797  15818.370688  0.818342
# 1                     RandomForestRegressor  29.515135  16050.841598  0.815672
# 2                 GradientBoostingRegressor  27.960924  16784.440532  0.807247
# 6                              XGBRegressor  30.765939  18365.652737  0.789089
# 8                         AdaBoostRegressor  39.143028  20260.350185  0.767330
# 10                         BaggingRegressor  28.954374  21799.124956  0.749659
# 12  BaggingRegressor(RandomForestRegressor)  29.846349  27310.201804  0.686369
# 7                             LGBMRegressor  31.371738  36028.629261  0.586247
# 0                          LinearRegression  61.988581  56313.767646  0.353292
# 9              PolynomialFeatures(degree=3)  39.707817  73621.498708  0.154530
# 5                       KNeighborsRegressor  65.207939  77361.845216  0.111576
# 11       BaggingRegressor(LinearRegression)  61.379028  55438.641099  0.014684
# 4                                       SVR  62.708889  85802.987948  0.014638
